# %% [markdown]
# # Test
# Notebook for testing the code. Two instances are provided:
# - Small instance: 4 locations, 2 vessels, 3 bodies, 3 requests. It is solved without time constraints and with a relative gap of 10%.
# - Medium instance: 7 locations, 3 vessels, 3 bodies, 4 requests. It is solved with time constraint of 900 seconds and relative gap of 30%.

# %%
import matplotlib.pyplot as plt
from vessel_swap_body_class import vsbp
from instance_generator import generate_instance

# %%
generate_instance(n_nodes = 4, n_vessels = 2, n_bodies = 3, n_requests = 3)
random_test = vsbp("random_instance")
random_test.solve_vsbr(time_limit=600)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2023-06-29
# Set parameter MIPGap to value 0.1
# Set parameter TimeLimit to value 600
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 4 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 15906 rows, 5651 columns and 62278 nonzeros
# Model fingerprint: 0xb1a7f95c
# Variable types: 160 continuous, 5491 integer (5491 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+04]
#   Objective range  [1e+01, 1e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+04]
# Found heuristic solution: objective 30000.000000
# Presolve removed 8585 rows and 2211 columns
# Presolve time: 0.15s
# Presolved: 7321 rows, 3440 columns, 32488 nonzeros
# Variable types: 149 continuous, 3291 integer (3291 binary)
#
# Root relaxation: objective 1.000286e+04, 1212 iterations, 0.05 seconds (0.06 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 10002.8643    0   87 30000.0000 10002.8643  66.7%     -    0s
#      0     0 10005.6775    0  161 30000.0000 10005.6775  66.6%     -    0s
#      0     0 10012.2342    0  185 30000.0000 10012.2342  66.6%     -    0s
#      0     0 10012.5196    0  151 30000.0000 10012.5196  66.6%     -    0s
#      0     0 10012.5196    0  151 30000.0000 10012.5196  66.6%     -    0s
#      0     0 10013.9998    0  161 30000.0000 10013.9998  66.6%     -    0s
#      0     0 10020.8617    0  224 30000.0000 10020.8617  66.6%     -    0s
#      0     0 10021.7286    0  158 30000.0000 10021.7286  66.6%     -    0s
#      0     0 10021.8167    0  158 30000.0000 10021.8167  66.6%     -    0s
#      0     0 10021.8167    0  158 30000.0000 10021.8167  66.6%     -    0s
# H    0     0                    20278.264264 10021.8167  50.6%     -    0s
#      0     0 10022.6759    0  197 20278.2643 10022.6759  50.6%     -    0s
# H    0     0                    20259.645646 10022.6759  50.5%     -    0s
#      0     0 10023.1939    0  203 20259.6456 10023.1939  50.5%     -    0s
#      0     0 10023.1939    0  201 20259.6456 10023.1939  50.5%     -    0s
#      0     0 10024.1266    0  195 20259.6456 10024.1266  50.5%     -    0s
# H    0     0                    20211.111111 10024.4208  50.4%     -    0s
#      0     0 10024.4208    0  172 20211.1111 10024.4208  50.4%     -    0s
#      0     0 10032.1195    0  178 20211.1111 10032.1195  50.4%     -    1s
#      0     0 10032.1195    0  184 20211.1111 10032.1195  50.4%     -    1s
#      0     0 10035.3762    0  133 20211.1111 10035.3762  50.3%     -    1s
#      0     0 10035.3762    0  182 20211.1111 10035.3762  50.3%     -    1s
#      0     0 10035.3762    0  119 20211.1111 10035.3762  50.3%     -    1s
# H    0     0                    10311.765766 10035.3762  2.68%     -    1s
#      0     0 10035.3762    0  111 10311.7658 10035.3762  2.68%     -    1s
#
# Cutting planes:
#   Lift-and-project: 3
#   Cover: 87
#   Implied bound: 65
#   Clique: 12
#   MIR: 12
#   Flow cover: 15
#   Zero half: 12
#   RLT: 22
#   Relax-and-lift: 5
#
# Explored 1 nodes (4569 simplex iterations) in 1.21 seconds (0.93 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 5: 10311.8 20211.1 20259.6 ... 30000
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 1.031176576577e+04, best bound 1.003537622129e+04, gap 2.6803%
# Objective Function Value: 10311.765765765766

# %%
plt.figure(figsize=(20,18))
random_test.plot_solution()
# Out:
# ------------------------ Instance problem: ---------------------------------
#
# Vessel: 0 - start location: 0
# Vessel: 1 - start location: 1
#
# Body:   0 - start location: 0
# Body:   1 - start location: 1
# Body:   2 - start location: 0
#
# Request 0: pickup time window is [19933, 23355] delivery time window is [32008, 37745]
# Request 1: delivery time window is [9221, 10247]
# Request 2: pickup time window is [18272, 18302] delivery time window is [26258, 26544]
#
# ---------------------------- Solution: -------------------------------------
#
# Objective Function Value: 10311.77
#
# Request 0 handled by body 1 - Pickup at location 1 at 19933.0  - Delivery at location 3 at 32008.0
# Request 1 handled by body 0 - Delivery at location 3 at 9221.0
# Request 2 outsourced by trucks!
