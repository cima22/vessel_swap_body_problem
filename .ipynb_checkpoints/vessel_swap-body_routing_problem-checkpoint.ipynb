# %%
from gurobipy import *
from itertools import combinations
import numpy as np

# %%
def ri(low,high,m_one=0.):
    p = np.random.uniform(0,1)
    if(m_one < p):
        return np.random.randint(low,high)
    return -1

# %%
opt_mod = Model(name = "vessel swap body routing")
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2023-06-29

# %%
speed                  = 333
coupling_time          = 15
decoupling_time        = 15
body_capacity          = 50
max_bodies             = 3
n_nodes                = 4
n_vessels              = 2
n_bodies               = 3
n_requests             = 3
unscheduled_cost_coeff = 10000
service_time           = 2

# %%
distances = np.array([[0,64100,64700,59000,68800],
                     [64100,0,10900,6200,6800],
                     [64700,10900,0,5800,4100],
                     [59000,6200,5800,0,9800],
                     [68800,6800,4100,9800,0]
                     ])

# %%
Nodes = tuplelist()
for i in range(n_nodes):
    Nodes.append((i,1))

Vessels = tuplelist()
for i in range(n_vessels):
    Vessels.append((i,ri(0,n_nodes),0))

Bodies = tuplelist()
for i in range(n_bodies):
    vessel = ri(0,n_vessels)
    Bodies.append((i,vessel,Vessels[vessel][1]))

Requests = tuplelist()
for i in range(n_requests):
    at_body_id = ri(0,n_bodies,.7)
    pick_id    = -1 if at_body_id != -1 else ri(0,n_nodes)
    pick_from  = -1 if at_body_id != -1 else ri(0,21600)
    pick_to    = -1 if at_body_id != -1 else pick_from + ri(0,5760) 
    deliv_id   = ri(0,n_nodes)
    while(deliv_id == pick_id):
        deliv_id = ri(0,n_nodes)
    deliv_from = ri(0,21600) if at_body_id != -1 else pick_to + ri(7200,14400)
    deliv_to   = deliv_from + ri(0,5760) if at_body_id != -1 else deliv_from + ri(0,5760)
    num_containters = ri(1,body_capacity/2)
    Requests.append((i,pick_id,pick_from,pick_to,deliv_id,deliv_from,deliv_to,num_containters,at_body_id))
Requests
# Out:
# <gurobi.tuplelist (3 tuples, 9 values each):
#  ( 0 , -1 , -1   , -1   , 3 , 20669 , 21257 , 7 , 0  )
#  ( 1 , 0  , 7283 , 8286 , 2 , 16933 , 20531 , 6 , -1 )
#  ( 2 , 3  , 8213 , 8250 , 1 , 15748 , 16920 , 8 , -1 )
# >

# %%
nodes_requests  = {}
nodes_locations = {}
Pickup_nodes        = []
Pickup_nodes_copy   = []
Delivery_nodes      = []
Delivery_nodes_copy = []
for i in range(n_requests):
    if(Requests[i][1] != -1):
        label = "P_" + str(i)
        Pickup_nodes.append(label)
        nodes_requests[label] = i
        nodes_locations[label] = Requests[i][1]
        
        label_copy = "P'_" + str(i + n_requests)
        Pickup_nodes_copy.append(label_copy)
        nodes_requests[label_copy] = i
        nodes_locations[label_copy] = Requests[i][1]
    
    if(Requests[i][4] != -1):
        label = "D_" + str(i + 2*n_requests)
        Delivery_nodes.append(label)
        nodes_requests[label] = i
        nodes_locations[label] = Requests[i][4]
        
        label_copy = "D'_" + str(i + 3*n_requests)
        Delivery_nodes_copy.append(label_copy)
        nodes_requests[label_copy] = i
        nodes_locations[label_copy] = Requests[i][4]
        
I = Pickup_nodes + Pickup_nodes_copy + Delivery_nodes + Delivery_nodes_copy

J_0 = []
for i in range(n_vessels):
    label = "o_v_" + str(i)
    J_0.append(label)
    nodes_locations[label] = Vessels[i][1]
for i in range(n_bodies):
    label = "o_b_" + str(i)
    J_0.append(label)
    nodes_locations[label] = Bodies[i][2]
    
Dummy = ["sink"]
nodes_locations["sink"] = -1

N = J_0 + I + Dummy
print(N)
print(nodes_requests)
print(nodes_locations)
# Out:
# ['o_v_0', 'o_v_1', 'o_b_0', 'o_b_1', 'o_b_2', 'P_1', 'P_2', "P'_4", "P'_5", 'D_6', 'D_7', 'D_8', "D'_9", "D'_10", "D'_11", 'sink']
# {'D_6': 0, "D'_9": 0, 'P_1': 1, "P'_4": 1, 'D_7': 1, "D'_10": 1, 'P_2': 2, "P'_5": 2, 'D_8': 2, "D'_11": 2}
# {'D_6': 3, "D'_9": 3, 'P_1': 0, "P'_4": 0, 'D_7': 2, "D'_10": 2, 'P_2': 3, "P'_5": 3, 'D_8': 1, "D'_11": 1, 'o_v_0': 0, 'o_v_1': 2, 'o_b_0': 2, 'o_b_1': 0, 'o_b_2': 0, 'sink': -1}

# %%
A_1 = tuplelist()
A_2 = tuplelist()
A_3 = tuplelist()
A_4 = tuplelist()
A_5 = tuplelist()
A_sink = tuplelist()
A_D = tuplelist()
A = tuplelist()

# A_1
for o in J_0:
    for n in N:
        if(o == n):
            continue
        A_1.append((o,n))
###################################################################
# A_2
for p,p_copy in zip(Pickup_nodes,Pickup_nodes_copy):
    A_2.append((p,p_copy))
for p in Pickup_nodes:
    r = nodes_requests[p]
    for n in N:
        if(n[0] == 'P' or n[0] == 'D'):
            if(nodes_requests[n] == r):
                continue
        A_2.append((p,n))
###################################################################
# A_3
for p_copy,d in zip(Pickup_nodes_copy,Delivery_nodes):
    A_3.append((p_copy,d))
for p_copy in Pickup_nodes_copy:
    r = nodes_requests[p_copy]
    for n in N:
        if(n[0] == 'P' or n[0] == 'D'):
            if(nodes_requests[n] == r):
                continue
        A_3.append((p_copy,n))
###################################################################
# A_4
for d,d_copy in zip(Delivery_nodes,Delivery_nodes_copy):
    A_4.append((d,d_copy))
for d in Delivery_nodes:
    r = nodes_requests[d]
    for n in N:
        if(n[0] == 'P' or n[0] == 'D'):
            if(nodes_requests[n] == r):
                continue
        A_4.append((d,n))
###################################################################
# A_5
for d_copy in Delivery_nodes_copy:
    r = nodes_requests[d_copy]
    for n in N:
        if(n[0] == 'P' or n[0] == 'D'):
            if(nodes_requests[n] == r):
                continue
        A_5.append((d_copy,n))
###################################################################
# A_sink
for n in J_0 + I:
    A_sink.append((n,Dummy[0]))

A = A_1 + A_2 + A_3 + A_4 + A_5 #+ A_sink

# A_D
for i,j in A:
    if(nodes_locations[i] == nodes_locations[j]):
        A_D.append((i,j))
A_D += A_sink

# %%
travel_time = {}
for dep,arr in A:
    time = distances[nodes_locations[dep],nodes_locations[arr]] / speed if nodes_locations[arr] != -1 else 0
    
    if(dep in I and arr in I and nodes_requests[dep] == nodes_requests[arr]):
        service_time = coupling_time if A_1.select(dep,arr) else decoupling_time
        r = nodes_requests[dep]
        time = service_time * Requests[r][7]
       # if(dep[:2] == "P_" and arr[:3] == "P'_"):
       #     r = nodes_requests[dep]
       #     time = coupling_time * Requests[r][7]
       # if(dep[:2] == "D_" and arr[:3] == "D'_"):
       #     r = nodes_requests[dep]
       #     time = decoupling_time * Requests[r][7]
            
    travel_time[(dep,arr)] = time

# %%
z_v      = []
beta_b   = []
omega_bv = []
x_br     = []
delta_b  = []
gamma_r  = []
tau_a_v  = []
tau_d_v  = []
tau_a_b  = []
tau_d_b  = []
y_v      = []
phi_b    = []

for v in range(n_vessels):
    z_v.append({})
    for arc in A:
        z_v[v][arc] = opt_mod.addVar(name = "z_" + str(v) + "_(" + arc[0] + "," + arc[1] + ")", vtype = GRB.BINARY)

for b in range(n_bodies):
    beta_b.append({})
    for arc in A:
        beta_b[b][arc] = opt_mod.addVar(name = "beta_" + str(b) + "_(" + arc[0] + "," + arc[1] + ")", vtype = GRB.BINARY)

for v in range(n_vessels):
    omega_bv.append([])
    for b in range(n_bodies):
        omega_bv[v].append({})
        for arc in A:
            omega_bv[v][b][arc] = opt_mod.addVar(name = "omega_" + str(b) + "_" + str(v) + "_(" + arc[0] + "," + arc[1] + ")", vtype = GRB.BINARY)

for r in range(n_requests):
    x_br.append([])
    for b in range(n_bodies):
        x_br[r].append({})
        for arc in A:
            x_br[r][b][arc] = opt_mod.addVar(name = "x_" + str(b) + "_" + str(r) + "_(" + arc[0] + "," + arc[1] + ")", vtype = GRB.BINARY)

for b in range(n_bodies):
    delta_b.append({})
    for arc in A:
        delta_b[b][arc] = opt_mod.addVar(name = "delta_" + str(b) + "_(" + arc[0] + "," + arc[1] + ")", vtype = GRB.BINARY)

for r in range(n_requests):
    gamma_r.append(opt_mod.addVar(name = "gamma_" + str(r), vtype = GRB.BINARY))

for v in range(n_vessels):
    tau_a_v.append({})
    for n in N:
        tau_a_v[v][n] = opt_mod.addVar(name = "tau_a_" + str(v) + "_" + n, vtype = GRB.CONTINUOUS, lb = 0)

for v in range(n_vessels):
    tau_d_v.append({})
    for n in N:
        tau_d_v[v][n] = opt_mod.addVar(name = "tau_d_" + str(v) + "_" + n, vtype = GRB.CONTINUOUS, lb = 0)

for b in range(n_bodies):
    tau_a_b.append({})
    for n in N:
        tau_a_b[b][n] = opt_mod.addVar(name = "tau_B_a_" + str(b) + "_" + n, vtype = GRB.CONTINUOUS, lb = 0)

for b in range(n_bodies):
    tau_d_b.append({})
    for n in N:
        tau_d_b[b][n] = opt_mod.addVar(name = "tau_B_d_" + str(b) + "_" + n, vtype = GRB.CONTINUOUS, lb = 0)

for v in range(n_vessels):
    y_v.append({})
    for i in N:
        for j in N:
            if(i == j):
                continue
            y_v[v][(i,j)] = opt_mod.addVar(name = "y_" + str(v) + "_(" + i + "," + j + ")", vtype = GRB.BINARY)

for b in range(n_bodies):
    phi_b.append({})
    for i in N:
        for j in N:
            if(i == j):
                continue
            phi_b[b][(i,j)] = opt_mod.addVar(name = "phi_" + str(b) + "_(" + i + "," + j + ")", vtype = GRB.BINARY)

opt_mod.update()

# %%
obj_fn = quicksum(quicksum(travel_time[a]*z_v[v][a] for a in A) for v in range(n_vessels)) + quicksum(unscheduled_cost_coeff * (1 - gamma_r[r]) for r in range(n_requests))
opt_mod.setObjective(obj_fn,GRB.MINIMIZE)

# %%
# Routing for vessels and bodies costraints

c_2 = []
c_3 = []
c_4 = {}

for v in range(n_vessels):
    c_2.append(
        opt_mod.addConstr(
            quicksum(
                z_v[v][arc] for arc in A.select(J_0[v],"*")) == 1))
    
for v in range(n_vessels):
    c_3.append(
        opt_mod.addConstr(
            quicksum(
                z_v[v][arc] for arc in A_sink) == 1))

for v in range(n_vessels):
    for i in I:
        c_4[(v,i)] = opt_mod.addConstr(
            quicksum(z_v[v][arc] for arc in A.select("*",i)) == quicksum(z_v[v][arc] for arc in A.select(i,"*")))
        
c_5 = []
c_6 = []
c_7 = {}

for b in range(n_bodies):
    c_5.append(
        opt_mod.addConstr(
            quicksum(
                beta_b[b][arc] for arc in A.select(J_0[n_vessels + b],"*")) == 1))
    
for b in range(n_bodies):
    c_6.append(
        opt_mod.addConstr(
            quicksum(
                beta_b[b][arc] for arc in A_sink) == 1))

for b in range(n_bodies):
    for i in I:
        c_7[(b,i)] = opt_mod.addConstr(
            quicksum(beta_b[b][arc] for arc in A.select("*",i)) == quicksum(beta_b[b][arc] for arc in A.select(i,"*")))

c_8 = {}
c_9 = {}

for b in range(n_bodies):
    for arc in A_D:
        c_8[(b,arc)] = opt_mod.addConstr(
            beta_b[b][arc] == delta_b[b][arc] + quicksum(omega_bv[v][b][arc] for v in range(n_vessels)))

for b in range(n_bodies):
    for arc in set(A).difference(A_D):
        c_9[(b,arc)] = opt_mod.addConstr(
            beta_b[b][arc] == quicksum(omega_bv[v][b][arc] for v in range(n_vessels)))

# %%
# Sub-tour elimination for vessel routes
c_10 = {}
c_11 = {}
c_12 = {}
c_13 = {}

for v in range(n_vessels):
    for arc in A:
        c_10[(v,arc)] = opt_mod.addConstr(z_v[v][arc] <= y_v[v][arc])

for v in range(n_vessels):
    for i,j in [(i,j) for (i,j) in A if A.select(j,i)]:
        c_11[v,(i,j)] = opt_mod.addConstr(y_v[v][(i,j)] + y_v[v][(j,i)] == 1)
        
for v in range(n_vessels):
    for i,j in [(i,j) for (i,j) in A if not A.select(j,i)]:
        c_12[v,(i,j)]  = opt_mod.addConstr(y_v[v][(i,j)] == 1)
        
for v in range(n_vessels):
    for i,j in A:
        for _,l in A.select(j,"*"):
            if A.select(l,i):
                c_13[v,(i,j,l)] = opt_mod.addConstr(y_v[v][(i,j)] + y_v[v][(j,l)] + y_v[v][(l,i)] <= 2)

# %%
# Sub-tour elimination for body routes
c_14 = {}
c_15 = {}
c_16 = {}
c_17 = {}

for b in range(n_bodies):
    for arc in A:
        c_14[(b,arc)] = opt_mod.addConstr(beta_b[b][arc] <= phi_b[b][arc])

for b in range(n_bodies):
    for i,j in [(i,j) for (i,j) in A if A.select(j,i)]:
        c_15[b,(i,j)] = opt_mod.addConstr(phi_b[b][(i,j)] + phi_b[b][(j,i)] == 1)
        
for b in range(n_bodies):
    for i,j in [(i,j) for (i,j) in A if not A.select(j,i)]:
        c_16[b,(i,j)] = opt_mod.addConstr(phi_b[b][(i,j)] == 1)
        
for b in range(n_bodies):
    for i,j in A:
        for _,l in A.select(j,"*"):
            if A.select(l,i):
                c_17[b,(i,j,l)] = opt_mod.addConstr(phi_b[b][(i,j)] + phi_b[b][(j,l)] + phi_b[b][(l,i)] <= 2)

# %%
# Capacity constraints
c_18 = {}
c_19 = {}

for b in range(n_bodies):
    for arc in A:
        c_18[v,arc] = opt_mod.addConstr(
            quicksum(
                Requests[r][7]*x_br[r][b][arc] for r in range(n_requests)) <= body_capacity*beta_b[b][arc])

for v in range(n_vessels):
    for arc in A:
        c_19[v,arc] = opt_mod.addConstr(
            quicksum(
                omega_bv[v][b][arc] for b in range(n_bodies)) <= max_bodies*z_v[v][arc])

# %%
# Serving requests
c_20 = {}
c_21 = {}
c_22 = {}
c_23 = {}
c_24 = {}

for i in Pickup_nodes + Delivery_nodes:
    r = nodes_requests[i]
    n = int(i[2:]) + n_requests
    copy_i = i[0] + "'_" + str(n)
    arc = A.select(i,copy_i)[0]
    c_20[i] = opt_mod.addConstr(
        quicksum(x_br[r][b][arc] for b in range(n_bodies)) == gamma_r[r])

for b in range(n_bodies):
    for p in Pickup_nodes:
        r = nodes_requests[p]
        if(Requests[r][1] == -1 or Requests[r][4] == -1):
            continue
        n = int(p[2:])
        copy_p   = "P'_" + str(n + n_requests)
        d        = "D_"  + str(n + 2*n_requests)
        copy_d   = "D'_" + str(n + 3*n_requests)
        arc_p = A_2.select(p,copy_p)[0]
        arc_d = A_4.select(d,copy_d)[0]
        c_21[b,i] = opt_mod.addConstr(x_br[r][b][arc_p] == x_br[r][b][arc_d])

for b in range(n_bodies):
    for i in Pickup_nodes:
        r = nodes_requests[i]
        if(Requests[r][1] == -1 or Requests[r][4] == -1):
            continue
        copy_d = "D'_" + str(int(i[2:]) + 3*n_requests)
        for j in N:
            if(j == i or j == copy_d or j == "sink"):
                continue
            c_22[b,i,j] = opt_mod.addConstr(
                                        quicksum(x_br[r][b][A.select(j,k)[0]] for k in N if k != i and A.select(j,k)) ==
                                        quicksum(x_br[r][b][A.select(k,j)[0]] for k in N if k != copy_d and A.select(k,j)))
    
for i in Delivery_nodes:
    r = nodes_requests[i]
    if(Requests[r][1] != -1):
        continue
    b = Requests[r][8]
    copy_i = "D'_" + str(int(i[2:]) + n_requests)
    arc = A_4.select(i,copy_i)[0]
    c_23[i] = opt_mod.addConstr(x_br[r][b][arc] == gamma_r[r])

for i in N:
    for r in range(n_requests):
        for b1,b2 in combinations(range(n_bodies),r=2):
            c_24[i,r,b1,b2] = opt_mod.addConstr(
                                                quicksum(x_br[r][b1][arc] for arc in A.select("*",i)) +
                                                quicksum(x_br[r][b2][arc] for arc in A.select(i,"*")) <= 1)

# %%
# Updating arrival/departure times
T_max = max(Requests, key = lambda x : x[6])[6]
c_25 = {}
c_26 = {}

for v in range(n_vessels):
    for arc in A:
        c_25[v,arc] = opt_mod.addConstr(tau_a_v[v][arc[1]] >= 
                                        tau_d_v[v][arc[0]] + travel_time[arc] * z_v[v][arc] - T_max * (1 - z_v[v][arc]))
    
for b in range(n_vessels):
    for arc in A:
        c_26[v,arc] = opt_mod.addConstr(tau_a_b[b][arc[1]] >= 
                                        tau_d_b[b][arc[0]] + travel_time[arc] * beta_b[b][arc] - T_max * (1 - beta_b[b][arc]))

# %%
# Departures after arrivals
c_27 = {}
c_28 = {}

for v in range(n_vessels):
    for i in N:
        c_27[v,i] = opt_mod.addConstr(tau_d_v[v][i] >= tau_a_v[v][i])
    
for b in range(n_bodies):
    for i in N:
        c_28[v,i] = opt_mod.addConstr(tau_d_b[b][i] >= tau_a_b[b][i])

# %%
# Attaching and detaching times
c_29 = {}
c_30 = {}

for v in range(n_vessels):
    for b in range(n_bodies):
        for i in N:
            if(i == "o_b_" + str(b) or i == "sink"):
                continue
            c_29[v,b,i] = opt_mod.addConstr(tau_d_v[v][i] >= 
                                            tau_a_v[v][i] + decoupling_time +
                                            T_max * quicksum(omega_bv[v][b][arc] for arc in A.select("*",i)) -
                                            T_max * quicksum(omega_bv[v][b][arc] for arc in A.select(i,"*")) -
                                            T_max)
            
            c_30[v,b,i] = opt_mod.addConstr(tau_d_v[v][i] >= 
                                            tau_a_v[v][i] + decoupling_time -
                                            T_max * quicksum(omega_bv[v][b][arc] for arc in A.select("*",i)) +
                                            T_max * quicksum(omega_bv[v][b][arc] for arc in A.select(i,"*")) -
                                            T_max)

# %%
# Vessel arrives before body
c_31 = {}
c_32 = {}
c_33 = {}
c_34 = {}

for v in range(n_vessels):
    for b in range(n_bodies):
        for i in N:
            c_31[v,b,i] = opt_mod.addConstr(tau_a_b[b][i] >=
                                            tau_a_v[v][i] + 
                                            T_max * quicksum(omega_bv[v][b][arc] for arc in A.select("*",i)) - T_max)
            c_32[v,b,i] = opt_mod.addConstr(tau_d_b[b][i] >=
                                            tau_d_v[v][i] + 
                                            T_max * quicksum(omega_bv[v][b][arc] for arc in A.select("*",i)) - T_max)
            c_33[v,b,i] = opt_mod.addConstr(tau_a_v[v][i] >=
                                            tau_a_b[b][i] + 
                                            T_max * quicksum(omega_bv[v][b][arc] for arc in A.select(i,"*")) - T_max)
            c_34[v,b,i] = opt_mod.addConstr(tau_d_v[v][i] >=
                                            tau_d_b[b][i] + 
                                            T_max * quicksum(omega_bv[v][b][arc] for arc in A.select(i,"*")) - T_max)

# %%
# Time windows
c_35 = {}
c_36 = {}
c_37 = {}
c_38 = {}

for b in range(n_bodies):
    for i in Pickup_nodes:
        r = nodes_requests[i]
        t = Requests[r][2]
        c_35[b,i] = opt_mod.addConstr(tau_d_b[b][i] >= t * gamma_r[r])
        
    for i in Delivery_nodes:
        r = nodes_requests[i]
        t = Requests[r][5]
        c_36[b,i] = opt_mod.addConstr(tau_d_b[b][i] >= t * gamma_r[r])
        
    for i in Pickup_nodes_copy:
        r = nodes_requests[i]
        t = Requests[r][3]
        c_37[b,i] = opt_mod.addConstr(tau_a_b[b][i] >= t * gamma_r[r])
        
    for i in Delivery_nodes_copy:
        r = nodes_requests[i]
        t = Requests[r][6]
        c_38[b,i] = opt_mod.addConstr(tau_a_b[b][i] >= t * gamma_r[r])

# %%
# Transfers at non-client nodes

# %%
# Valid inequalities

c_44 = {}
c_45 = {}

for i in Pickup_nodes:
    r = nodes_requests[i]
    c_44[i] = opt_mod.addConstr(quicksum(
                                    quicksum(
                                        x_br[r][b][arc] for arc in A.select("*",i))
                                    for b in range(n_bodies)) == 0)

for i in Delivery_nodes_copy:
    r = nodes_requests[i]
    c_45[i] = opt_mod.addConstr(quicksum(
                                    quicksum(
                                        x_br[r][b][arc] for arc in A.select(i,"*"))
                                    for b in range(n_bodies)) == 0)

# %%
opt_mod.update()
opt_mod.optimize()
print(f'Objective Function Value: {opt_mod.objVal}')
for v in opt_mod.getVars():
    print(f'{v.varName}: {v.x}')
# Out:
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 4 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 15602 rows, 6101 columns and 60763 nonzeros
# Model fingerprint: 0x9bd9646a
# Variable types: 160 continuous, 5941 integer (5941 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [2e+01, 1e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Found heuristic solution: objective 30000.000000
# Presolve removed 8165 rows and 2291 columns
# Presolve time: 0.07s
# Presolved: 7437 rows, 3810 columns, 34956 nonzeros
# Variable types: 160 continuous, 3650 integer (3650 binary)
#
# Root relaxation: objective 3.462033e+01, 3950 iterations, 0.24 seconds (0.29 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   34.62033    0   68 30000.0000   34.62033   100%     -    0s
#      0     0   39.75608    0  158 30000.0000   39.75608   100%     -    0s
#      0     0   39.75608    0  147 30000.0000   39.75608   100%     -    0s
#      0     0   42.55017    0  301 30000.0000   42.55017   100%     -    1s
# H    0     0                    10230.630631   44.88803   100%     -    1s
#      0     0   44.88803    0  291 10230.6306   44.88803   100%     -    1s
#      0     0   44.97014    0  287 10230.6306   44.97014   100%     -    1s
#      0     0   44.99585    0  253 10230.6306   44.99585   100%     -    1s
#      0     0   44.99585    0  253 10230.6306   44.99585   100%     -    1s
#      0     0   47.90932    0  264 10230.6306   47.90932   100%     -    1s
#      0     0   48.16221    0  294 10230.6306   48.16221   100%     -    1s
#      0     0   48.28618    0  297 10230.6306   48.28618   100%     -    1s
#      0     0   48.52587    0  277 10230.6306   48.52587   100%     -    1s
#      0     0   48.53694    0  282 10230.6306   48.53694   100%     -    1s
#      0     0   48.53782    0  284 10230.6306   48.53782   100%     -    1s
#      0     0   49.79209    0  271 10230.6306   49.79209   100%     -    1s
# H    0     0                     425.2252252   49.79209  88.3%     -    1s
#      0     0   50.60910    0  233  425.22523   50.60910  88.1%     -    1s
#      0     0   50.76278    0  266  425.22523   50.76278  88.1%     -    1s
#      0     0   50.76303    0  230  425.22523   50.76303  88.1%     -    1s
#      0     0   50.76360    0  268  425.22523   50.76360  88.1%     -    1s
#      0     0   50.84211    0  280  425.22523   50.84211  88.0%     -    1s
#      0     0   51.08853    0  269  425.22523   51.08853  88.0%     -    1s
#      0     0   51.29383    0  337  425.22523   51.29383  87.9%     -    1s
#      0     0   51.34739    0  294  425.22523   51.34739  87.9%     -    2s
#      0     0   51.44504    0  268  425.22523   51.44504  87.9%     -    2s
#      0     0   51.44504    0  267  425.22523   51.44504  87.9%     -    2s
#      0     0   51.44504    0  274  425.22523   51.44504  87.9%     -    2s
#      0     0   51.44504    0  308  425.22523   51.44504  87.9%     -    2s
#      0     0   52.80919    0  296  425.22523   52.80919  87.6%     -    2s
# H    0     0                     230.3303303   52.80919  77.1%     -    2s
#      0     0   52.80919    0  304  230.33033   52.80919  77.1%     -    2s
#      0     0   53.07064    0  318  230.33033   53.07064  77.0%     -    2s
#      0     0   53.10809    0  322  230.33033   53.10809  76.9%     -    2s
#      0     0   53.11065    0  325  230.33033   53.11065  76.9%     -    2s
#      0     0   53.63011    0  285  230.33033   53.63011  76.7%     -    2s
#      0     0   53.63011    0  295  230.33033   53.63011  76.7%     -    2s
#      0     0   53.82448    0  258  230.33033   53.82448  76.6%     -    2s
#      0     0   54.12156    0  252  230.33033   54.12156  76.5%     -    2s
#      0     0   54.12180    0  276  230.33033   54.12180  76.5%     -    2s
#      0     0   54.12877    0  281  230.33033   54.12877  76.5%     -    2s
#      0     0   54.12899    0  294  230.33033   54.12899  76.5%     -    2s
#      0     0   54.17820    0  250  230.33033   54.17820  76.5%     -    2s
#      0     0   54.17820    0  256  230.33033   54.17820  76.5%     -    2s
#      0     0   54.17895    0  273  230.33033   54.17895  76.5%     -    2s
#      0     0   54.17895    0  265  230.33033   54.17895  76.5%     -    2s
#      0     0   54.20582    0  247  230.33033   54.20582  76.5%     -    2s
#      0     0   54.20582    0  185  230.33033   54.20582  76.5%     -    3s
#      0     0   54.27852    0  241  230.33033   54.27852  76.4%     -    3s
#      0     0   62.23605    0  274  230.33033   62.23605  73.0%     -    4s
#      0     0   62.35164    0  345  230.33033   62.35164  72.9%     -    4s
#      0     0   62.38764    0  315  230.33033   62.38764  72.9%     -    4s
#      0     0   62.38764    0  313  230.33033   62.38764  72.9%     -    4s
#      0     0   76.77678    0  347  230.33033   76.77678  66.7%     -    4s
#      0     0   76.77678    0  321  230.33033   76.77678  66.7%     -    4s
#      0     0   78.99405    0  368  230.33033   78.99405  65.7%     -    4s
#      0     0   80.73458    0  376  230.33033   80.73458  64.9%     -    4s
#      0     0   80.73458    0  365  230.33033   80.73458  64.9%     -    4s
#      0     0   81.09932    0  414  230.33033   81.09932  64.8%     -    4s
#      0     0   81.09932    0  340  230.33033   81.09932  64.8%     -    4s
#      0     0   81.09932    0  336  230.33033   81.09932  64.8%     -    5s
#      0     0   81.42758    0  241  230.33033   81.42758  64.6%     -    5s
#      0     0   98.45230    0  306  230.33033   98.45230  57.3%     -    5s
#      0     0   99.79980    0  270  230.33033   99.79980  56.7%     -    5s
# H    0     0                     228.5285285   99.79980  56.3%     -    5s
#      0     0   99.79980    0  323  228.52853   99.79980  56.3%     -    5s
#      0     0   99.79980    0  307  228.52853   99.79980  56.3%     -    5s
#      0     0   99.79980    0  310  228.52853   99.79980  56.3%     -    5s
#      0     0   99.79980    0  303  228.52853   99.79980  56.3%     -    5s
#      0     0   99.79980    0  287  228.52853   99.79980  56.3%     -    5s
#      0     0  100.20020    0  309  228.52853  100.20020  56.2%     -    5s
#      0     0  100.20020    0  293  228.52853  100.20020  56.2%     -    5s
#      0     0  100.85085    0  351  228.52853  100.85085  55.9%     -    5s
#      0     0  100.85085    0  304  228.52853  100.85085  55.9%     -    5s
#      0     0  100.85085    0  310  228.52853  100.85085  55.9%     -    5s
#      0     0  100.85085    0  301  228.52853  100.85085  55.9%     -    6s
#      0     0  101.62663    0  345  228.52853  101.62663  55.5%     -    6s
#      0     0  101.62663    0  326  228.52853  101.62663  55.5%     -    6s
#      0     0  164.41441    0  319  228.52853  164.41441  28.1%     -    6s
#      0     0  164.41441    0  286  228.52853  164.41441  28.1%     -    6s
#      0     2  164.41441    0  284  228.52853  164.41441  28.1%     -    7s
# H   27    29                     227.3273273  170.31317  25.1%   256    8s
#
# Cutting planes:
#   Gomory: 8
#   Cover: 36
#   MIR: 43
#   GUB cover: 2
#   Zero half: 17
#   RLT: 13
#
# Explored 169 nodes (60015 simplex iterations) in 9.19 seconds (9.41 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 6: 227.327 228.529 230.33 ... 30000
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.273273273273e+02, best bound 2.273273273273e+02, gap 0.0000%
# Objective Function Value: 227.32732732732984
# z_0_(o_v_0,o_v_1): -0.0
# z_0_(o_v_0,o_b_0): -0.0
# z_0_(o_v_0,o_b_1): 1.0
# z_0_(o_v_0,o_b_2): -0.0
# z_0_(o_v_0,P_1): -0.0
# z_0_(o_v_0,P_2): -0.0
# z_0_(o_v_0,P'_4): -0.0
# z_0_(o_v_0,P'_5): -0.0
# z_0_(o_v_0,D_6): -0.0
# z_0_(o_v_0,D_7): -0.0
# z_0_(o_v_0,D_8): -0.0
# z_0_(o_v_0,D'_9): -0.0
# z_0_(o_v_0,D'_10): -0.0
# z_0_(o_v_0,D'_11): -0.0
# z_0_(o_v_0,sink): -0.0
# z_0_(o_v_1,o_v_0): 0.0
# z_0_(o_v_1,o_b_0): -0.0
# z_0_(o_v_1,o_b_1): 0.0
# z_0_(o_v_1,o_b_2): 0.0
# z_0_(o_v_1,P_1): 0.0
# z_0_(o_v_1,P_2): -0.0
# z_0_(o_v_1,P'_4): 0.0
# z_0_(o_v_1,P'_5): -0.0
# z_0_(o_v_1,D_6): 0.0
# z_0_(o_v_1,D_7): -0.0
# z_0_(o_v_1,D_8): 0.0
# z_0_(o_v_1,D'_9): -0.0
# z_0_(o_v_1,D'_10): -0.0
# z_0_(o_v_1,D'_11): -0.0
# z_0_(o_v_1,sink): -0.0
# z_0_(o_b_0,o_v_0): 0.0
# z_0_(o_b_0,o_v_1): -0.0
# z_0_(o_b_0,o_b_1): 0.0
# z_0_(o_b_0,o_b_2): 0.0
# z_0_(o_b_0,P_1): 0.0
# z_0_(o_b_0,P_2): -0.0
# z_0_(o_b_0,P'_4): 0.0
# z_0_(o_b_0,P'_5): -0.0
# z_0_(o_b_0,D_6): -0.0
# z_0_(o_b_0,D_7): -0.0
# z_0_(o_b_0,D_8): -0.0
# z_0_(o_b_0,D'_9): -0.0
# z_0_(o_b_0,D'_10): -0.0
# z_0_(o_b_0,D'_11): -0.0
# z_0_(o_b_0,sink): 1.0
# z_0_(o_b_1,o_v_0): -0.0
# z_0_(o_b_1,o_v_1): -0.0
# z_0_(o_b_1,o_b_0): -0.0
# z_0_(o_b_1,o_b_2): -0.0
# z_0_(o_b_1,P_1): -0.0
# z_0_(o_b_1,P_2): -0.0
# z_0_(o_b_1,P'_4): -0.0
# z_0_(o_b_1,P'_5): -0.0
# z_0_(o_b_1,D_6): -0.0
# z_0_(o_b_1,D_7): -0.0
# z_0_(o_b_1,D_8): -0.0
# z_0_(o_b_1,D'_9): -0.0
# z_0_(o_b_1,D'_10): -0.0
# z_0_(o_b_1,D'_11): -0.0
# z_0_(o_b_1,sink): -0.0
# z_0_(o_b_2,o_v_0): -0.0
# z_0_(o_b_2,o_v_1): -0.0
# z_0_(o_b_2,o_b_0): -0.0
# z_0_(o_b_2,o_b_1): -0.0
# z_0_(o_b_2,P_1): 0.0
# z_0_(o_b_2,P_2): -0.0
# z_0_(o_b_2,P'_4): -0.0
# z_0_(o_b_2,P'_5): -0.0
# z_0_(o_b_2,D_6): -0.0
# z_0_(o_b_2,D_7): -0.0
# z_0_(o_b_2,D_8): -0.0
# z_0_(o_b_2,D'_9): -0.0
# z_0_(o_b_2,D'_10): -0.0
# z_0_(o_b_2,D'_11): -0.0
# z_0_(o_b_2,sink): -0.0
# z_0_(P_1,P'_4): -0.0
# z_0_(P_2,P'_5): -0.0
# z_0_(P_1,o_v_0): -0.0
# z_0_(P_1,o_v_1): -0.0
# z_0_(P_1,o_b_0): -0.0
# z_0_(P_1,o_b_1): 0.0
# z_0_(P_1,o_b_2): -0.0
# z_0_(P_1,P_2): -0.0
# z_0_(P_1,P'_5): -0.0
# z_0_(P_1,D_6): -0.0
# z_0_(P_1,D_8): -0.0
# z_0_(P_1,D'_9): -0.0
# z_0_(P_1,D'_11): -0.0
# z_0_(P_1,sink): -0.0
# z_0_(P_2,o_v_0): 0.0
# z_0_(P_2,o_v_1): -0.0
# z_0_(P_2,o_b_0): -0.0
# z_0_(P_2,o_b_1): 0.0
# z_0_(P_2,o_b_2): 0.0
# z_0_(P_2,P_1): 0.0
# z_0_(P_2,P'_4): 0.0
# z_0_(P_2,D_6): -0.0
# z_0_(P_2,D_7): -0.0
# z_0_(P_2,D'_9): -0.0
# z_0_(P_2,D'_10): -0.0
# z_0_(P_2,sink): -0.0
# z_0_(P'_4,D_6): 0.0
# z_0_(P'_5,D_7): 0.0
# z_0_(P'_4,o_v_0): -0.0
# z_0_(P'_4,o_v_1): -0.0
# z_0_(P'_4,o_b_0): -0.0
# z_0_(P'_4,o_b_1): -0.0
# z_0_(P'_4,o_b_2): -0.0
# z_0_(P'_4,P_2): -0.0
# z_0_(P'_4,P'_5): -0.0
# z_0_(P'_4,D_6): 0.0
# z_0_(P'_4,D_8): -0.0
# z_0_(P'_4,D'_9): -0.0
# z_0_(P'_4,D'_11): -0.0
# z_0_(P'_4,sink): -0.0
# z_0_(P'_5,o_v_0): 0.0
# z_0_(P'_5,o_v_1): -0.0
# z_0_(P'_5,o_b_0): -0.0
# z_0_(P'_5,o_b_1): 0.0
# z_0_(P'_5,o_b_2): 0.0
# z_0_(P'_5,P_1): 0.0
# z_0_(P'_5,P'_4): 0.0
# z_0_(P'_5,D_6): -0.0
# z_0_(P'_5,D_7): -0.0
# z_0_(P'_5,D'_9): -0.0
# z_0_(P'_5,D'_10): -0.0
# z_0_(P'_5,sink): -0.0
# z_0_(D_6,D'_9): -0.0
# z_0_(D_7,D'_10): -0.0
# z_0_(D_8,D'_11): -0.0
# z_0_(D_6,o_v_0): 0.0
# z_0_(D_6,o_v_1): -0.0
# z_0_(D_6,o_b_0): 0.0
# z_0_(D_6,o_b_1): 0.0
# z_0_(D_6,o_b_2): 0.0
# z_0_(D_6,P_1): 0.0
# z_0_(D_6,P_2): -0.0
# z_0_(D_6,P'_4): 0.0
# z_0_(D_6,P'_5): -0.0
# z_0_(D_6,D_7): -0.0
# z_0_(D_6,D_8): -0.0
# z_0_(D_6,D'_10): -0.0
# z_0_(D_6,D'_11): -0.0
# z_0_(D_6,sink): -0.0
# z_0_(D_7,o_v_0): 0.0
# z_0_(D_7,o_v_1): -0.0
# z_0_(D_7,o_b_0): -0.0
# z_0_(D_7,o_b_1): 0.0
# z_0_(D_7,o_b_2): 0.0
# z_0_(D_7,P_2): -0.0
# z_0_(D_7,P'_5): -0.0
# z_0_(D_7,D_6): -0.0
# z_0_(D_7,D_8): -0.0
# z_0_(D_7,D'_9): -0.0
# z_0_(D_7,D'_11): -0.0
# z_0_(D_7,sink): -0.0
# z_0_(D_8,o_v_0): 0.0
# z_0_(D_8,o_v_1): -0.0
# z_0_(D_8,o_b_0): -0.0
# z_0_(D_8,o_b_1): 0.0
# z_0_(D_8,o_b_2): 0.0
# z_0_(D_8,P_1): 0.0
# z_0_(D_8,P'_4): 0.0
# z_0_(D_8,D_6): -0.0
# z_0_(D_8,D_7): -0.0
# z_0_(D_8,D'_9): -0.0
# z_0_(D_8,D'_10): -0.0
# z_0_(D_8,sink): 0.0
# z_0_(D'_9,o_v_0): 0.0
# z_0_(D'_9,o_v_1): -0.0
# z_0_(D'_9,o_b_0): -0.0
# z_0_(D'_9,o_b_1): 0.0
# z_0_(D'_9,o_b_2): 0.0
# z_0_(D'_9,P_1): 0.0
# z_0_(D'_9,P_2): -0.0
# z_0_(D'_9,P'_4): 0.0
# z_0_(D'_9,P'_5): -0.0
# z_0_(D'_9,D_7): -0.0
# z_0_(D'_9,D_8): -0.0
# z_0_(D'_9,D'_10): -0.0
# z_0_(D'_9,D'_11): 0.0
# z_0_(D'_9,sink): -0.0
# z_0_(D'_10,o_v_0): 0.0
# z_0_(D'_10,o_v_1): -0.0
# z_0_(D'_10,o_b_0): -0.0
# z_0_(D'_10,o_b_1): 0.0
# z_0_(D'_10,o_b_2): 0.0
# z_0_(D'_10,P_2): -0.0
# z_0_(D'_10,P'_5): -0.0
# z_0_(D'_10,D_6): -0.0
# z_0_(D'_10,D_8): -0.0
# z_0_(D'_10,D'_9): -0.0
# z_0_(D'_10,D'_11): -0.0
# z_0_(D'_10,sink): -0.0
# z_0_(D'_11,o_v_0): 0.0
# z_0_(D'_11,o_v_1): -0.0
# z_0_(D'_11,o_b_0): -0.0
# z_0_(D'_11,o_b_1): 0.0
# z_0_(D'_11,o_b_2): 0.0
# z_0_(D'_11,P_1): 0.0
# z_0_(D'_11,P'_4): 0.0
# z_0_(D'_11,D_6): -0.0
# z_0_(D'_11,D_7): -0.0
# z_0_(D'_11,D'_9): 0.0
# z_0_(D'_11,D'_10): -0.0
# z_0_(D'_11,sink): -0.0
# z_1_(o_v_0,o_v_1): -0.0
# z_1_(o_v_0,o_b_0): -0.0
# z_1_(o_v_0,o_b_1): -0.0
# z_1_(o_v_0,o_b_2): -0.0
# z_1_(o_v_0,P_1): -0.0
# z_1_(o_v_0,P_2): 1.0
# z_1_(o_v_0,P'_4): -0.0
# z_1_(o_v_0,P'_5): -0.0
# z_1_(o_v_0,D_6): -0.0
# z_1_(o_v_0,D_7): -0.0
# z_1_(o_v_0,D_8): -0.0
# z_1_(o_v_0,D'_9): -0.0
# z_1_(o_v_0,D'_10): -0.0
# z_1_(o_v_0,D'_11): 0.0
# z_1_(o_v_0,sink): 0.0
# z_1_(o_v_1,o_v_0): 0.0
# z_1_(o_v_1,o_b_0): 1.0
# z_1_(o_v_1,o_b_1): 0.0
# z_1_(o_v_1,o_b_2): 0.0
# z_1_(o_v_1,P_1): 0.0
# z_1_(o_v_1,P_2): -0.0
# z_1_(o_v_1,P'_4): 0.0
# z_1_(o_v_1,P'_5): -0.0
# z_1_(o_v_1,D_6): -0.0
# z_1_(o_v_1,D_7): -0.0
# z_1_(o_v_1,D_8): -0.0
# z_1_(o_v_1,D'_9): -0.0
# z_1_(o_v_1,D'_10): -0.0
# z_1_(o_v_1,D'_11): -0.0
# z_1_(o_v_1,sink): -0.0
# z_1_(o_b_0,o_v_0): 0.0
# z_1_(o_b_0,o_v_1): -0.0
# z_1_(o_b_0,o_b_1): 0.0
# z_1_(o_b_0,o_b_2): 0.0
# z_1_(o_b_0,P_1): 0.0
# z_1_(o_b_0,P_2): -0.0
# z_1_(o_b_0,P'_4): 0.0
# z_1_(o_b_0,P'_5): -0.0
# z_1_(o_b_0,D_6): -0.0
# z_1_(o_b_0,D_7): -0.0
# z_1_(o_b_0,D_8): 1.0
# z_1_(o_b_0,D'_9): -0.0
# z_1_(o_b_0,D'_10): -0.0
# z_1_(o_b_0,D'_11): -0.0
# z_1_(o_b_0,sink): -0.0
# z_1_(o_b_1,o_v_0): -0.0
# z_1_(o_b_1,o_v_1): -0.0
# z_1_(o_b_1,o_b_0): -0.0
# z_1_(o_b_1,o_b_2): -0.0
# z_1_(o_b_1,P_1): -0.0
# z_1_(o_b_1,P_2): -0.0
# z_1_(o_b_1,P'_4): -0.0
# z_1_(o_b_1,P'_5): -0.0
# z_1_(o_b_1,D_6): -0.0
# z_1_(o_b_1,D_7): -0.0
# z_1_(o_b_1,D_8): -0.0
# z_1_(o_b_1,D'_9): -0.0
# z_1_(o_b_1,D'_10): -0.0
# z_1_(o_b_1,D'_11): -0.0
# z_1_(o_b_1,sink): -0.0
# z_1_(o_b_2,o_v_0): -0.0
# z_1_(o_b_2,o_v_1): -0.0
# z_1_(o_b_2,o_b_0): -0.0
# z_1_(o_b_2,o_b_1): -0.0
# z_1_(o_b_2,P_1): -0.0
# z_1_(o_b_2,P_2): -0.0
# z_1_(o_b_2,P'_4): -0.0
# z_1_(o_b_2,P'_5): -0.0
# z_1_(o_b_2,D_6): -0.0
# z_1_(o_b_2,D_7): -0.0
# z_1_(o_b_2,D_8): -0.0
# z_1_(o_b_2,D'_9): -0.0
# z_1_(o_b_2,D'_10): -0.0
# z_1_(o_b_2,D'_11): -0.0
# z_1_(o_b_2,sink): -0.0
# z_1_(P_1,P'_4): -0.0
# z_1_(P_2,P'_5): -0.0
# z_1_(P_1,o_v_0): -0.0
# z_1_(P_1,o_v_1): -0.0
# z_1_(P_1,o_b_0): -0.0
# z_1_(P_1,o_b_1): -0.0
# z_1_(P_1,o_b_2): -0.0
# z_1_(P_1,P_2): -0.0
# z_1_(P_1,P'_5): -0.0
# z_1_(P_1,D_6): -0.0
# z_1_(P_1,D_8): -0.0
# z_1_(P_1,D'_9): -0.0
# z_1_(P_1,D'_11): -0.0
# z_1_(P_1,sink): -0.0
# z_1_(P_2,o_v_0): 0.0
# z_1_(P_2,o_v_1): -0.0
# z_1_(P_2,o_b_0): -0.0
# z_1_(P_2,o_b_1): 0.0
# z_1_(P_2,o_b_2): 0.0
# z_1_(P_2,P_1): 0.0
# z_1_(P_2,P'_4): 0.0
# z_1_(P_2,D_6): -0.0
# z_1_(P_2,D_7): -0.0
# z_1_(P_2,D'_9): 1.0
# z_1_(P_2,D'_10): -0.0
# z_1_(P_2,sink): -0.0
# z_1_(P'_4,D_6): 0.0
# z_1_(P'_5,D_7): 0.0
# z_1_(P'_4,o_v_0): -0.0
# z_1_(P'_4,o_v_1): -0.0
# z_1_(P'_4,o_b_0): -0.0
# z_1_(P'_4,o_b_1): -0.0
# z_1_(P'_4,o_b_2): -0.0
# z_1_(P'_4,P_2): -0.0
# z_1_(P'_4,P'_5): -0.0
# z_1_(P'_4,D_6): 0.0
# z_1_(P'_4,D_8): -0.0
# z_1_(P'_4,D'_9): -0.0
# z_1_(P'_4,D'_11): -0.0
# z_1_(P'_4,sink): -0.0
# z_1_(P'_5,o_v_0): 0.0
# z_1_(P'_5,o_v_1): 0.0
# z_1_(P'_5,o_b_0): 1.0
# z_1_(P'_5,o_b_1): 0.0
# z_1_(P'_5,o_b_2): 0.0
# z_1_(P'_5,P_1): 0.0
# z_1_(P'_5,P'_4): 0.0
# z_1_(P'_5,D_6): -0.0
# z_1_(P'_5,D_7): -0.0
# z_1_(P'_5,D'_9): -0.0
# z_1_(P'_5,D'_10): -0.0
# z_1_(P'_5,sink): -0.0
# z_1_(D_6,D'_9): -0.0
# z_1_(D_7,D'_10): -0.0
# z_1_(D_8,D'_11): -0.0
# z_1_(D_6,o_v_0): 0.0
# z_1_(D_6,o_v_1): -0.0
# z_1_(D_6,o_b_0): 0.0
# z_1_(D_6,o_b_1): 0.0
# z_1_(D_6,o_b_2): 0.0
# z_1_(D_6,P_1): 0.0
# z_1_(D_6,P_2): -0.0
# z_1_(D_6,P'_4): 0.0
# z_1_(D_6,P'_5): -0.0
# z_1_(D_6,D_7): -0.0
# z_1_(D_6,D_8): -0.0
# z_1_(D_6,D'_10): -0.0
# z_1_(D_6,D'_11): -0.0
# z_1_(D_6,sink): -0.0
# z_1_(D_7,o_v_0): 0.0
# z_1_(D_7,o_v_1): -0.0
# z_1_(D_7,o_b_0): -0.0
# z_1_(D_7,o_b_1): 0.0
# z_1_(D_7,o_b_2): 0.0
# z_1_(D_7,P_2): -0.0
# z_1_(D_7,P'_5): -0.0
# z_1_(D_7,D_6): -0.0
# z_1_(D_7,D_8): -0.0
# z_1_(D_7,D'_9): -0.0
# z_1_(D_7,D'_11): -0.0
# z_1_(D_7,sink): -0.0
# z_1_(D_8,o_v_0): 0.0
# z_1_(D_8,o_v_1): -0.0
# z_1_(D_8,o_b_0): -0.0
# z_1_(D_8,o_b_1): 0.0
# z_1_(D_8,o_b_2): 0.0
# z_1_(D_8,P_1): 0.0
# z_1_(D_8,P'_4): 0.0
# z_1_(D_8,D_6): 0.0
# z_1_(D_8,D_7): -0.0
# z_1_(D_8,D'_9): -0.0
# z_1_(D_8,D'_10): -0.0
# z_1_(D_8,sink): 1.0
# z_1_(D'_9,o_v_0): 0.0
# z_1_(D'_9,o_v_1): 0.0
# z_1_(D'_9,o_b_0): -0.0
# z_1_(D'_9,o_b_1): 0.0
# z_1_(D'_9,o_b_2): 0.0
# z_1_(D'_9,P_1): 0.0
# z_1_(D'_9,P_2): -0.0
# z_1_(D'_9,P'_4): 0.0
# z_1_(D'_9,P'_5): 1.0
# z_1_(D'_9,D_7): -0.0
# z_1_(D'_9,D_8): 0.0
# z_1_(D'_9,D'_10): -0.0
# z_1_(D'_9,D'_11): -0.0
# z_1_(D'_9,sink): -0.0
# z_1_(D'_10,o_v_0): 0.0
# z_1_(D'_10,o_v_1): -0.0
# z_1_(D'_10,o_b_0): -0.0
# z_1_(D'_10,o_b_1): 0.0
# z_1_(D'_10,o_b_2): 0.0
# z_1_(D'_10,P_2): -0.0
# z_1_(D'_10,P'_5): -0.0
# z_1_(D'_10,D_6): -0.0
# z_1_(D'_10,D_8): -0.0
# z_1_(D'_10,D'_9): -0.0
# z_1_(D'_10,D'_11): -0.0
# z_1_(D'_10,sink): -0.0
# z_1_(D'_11,o_v_0): 0.0
# z_1_(D'_11,o_v_1): -0.0
# z_1_(D'_11,o_b_0): -0.0
# z_1_(D'_11,o_b_1): 0.0
# z_1_(D'_11,o_b_2): 0.0
# z_1_(D'_11,P_1): 0.0
# z_1_(D'_11,P'_4): 0.0
# z_1_(D'_11,D_6): -0.0
# z_1_(D'_11,D_7): -0.0
# z_1_(D'_11,D'_9): -0.0
# z_1_(D'_11,D'_10): -0.0
# z_1_(D'_11,sink): -0.0
# beta_0_(o_v_0,o_v_1): 0.0
# beta_0_(o_v_0,o_b_0): 0.0
# beta_0_(o_v_0,o_b_1): -0.0
# beta_0_(o_v_0,o_b_2): -0.0
# beta_0_(o_v_0,P_1): -0.0
# beta_0_(o_v_0,P_2): 1.0
# beta_0_(o_v_0,P'_4): -0.0
# beta_0_(o_v_0,P'_5): -0.0
# beta_0_(o_v_0,D_6): -0.0
# beta_0_(o_v_0,D_7): -0.0
# beta_0_(o_v_0,D_8): -0.0
# beta_0_(o_v_0,D'_9): -0.0
# beta_0_(o_v_0,D'_10): -0.0
# beta_0_(o_v_0,D'_11): -0.0
# beta_0_(o_v_0,sink): -0.0
# beta_0_(o_v_1,o_v_0): 0.0
# beta_0_(o_v_1,o_b_0): -0.0
# beta_0_(o_v_1,o_b_1): 0.0
# beta_0_(o_v_1,o_b_2): 0.0
# beta_0_(o_v_1,P_1): 0.0
# beta_0_(o_v_1,P_2): -0.0
# beta_0_(o_v_1,P'_4): 0.0
# beta_0_(o_v_1,P'_5): -0.0
# beta_0_(o_v_1,D_6): 0.0
# beta_0_(o_v_1,D_7): -0.0
# beta_0_(o_v_1,D_8): 0.0
# beta_0_(o_v_1,D'_9): -0.0
# beta_0_(o_v_1,D'_10): -0.0
# beta_0_(o_v_1,D'_11): -0.0
# beta_0_(o_v_1,sink): -0.0
# beta_0_(o_b_0,o_v_0): 0.0
# beta_0_(o_b_0,o_v_1): 1.0
# beta_0_(o_b_0,o_b_1): 0.0
# beta_0_(o_b_0,o_b_2): 0.0
# beta_0_(o_b_0,P_1): 0.0
# beta_0_(o_b_0,P_2): -0.0
# beta_0_(o_b_0,P'_4): 0.0
# beta_0_(o_b_0,P'_5): -0.0
# beta_0_(o_b_0,D_6): -0.0
# beta_0_(o_b_0,D_7): -0.0
# beta_0_(o_b_0,D_8): 0.0
# beta_0_(o_b_0,D'_9): -0.0
# beta_0_(o_b_0,D'_10): -0.0
# beta_0_(o_b_0,D'_11): -0.0
# beta_0_(o_b_0,sink): -0.0
# beta_0_(o_b_1,o_v_0): -0.0
# beta_0_(o_b_1,o_v_1): 0.0
# beta_0_(o_b_1,o_b_0): 0.0
# beta_0_(o_b_1,o_b_2): -0.0
# beta_0_(o_b_1,P_1): -0.0
# beta_0_(o_b_1,P_2): -0.0
# beta_0_(o_b_1,P'_4): -0.0
# beta_0_(o_b_1,P'_5): -0.0
# beta_0_(o_b_1,D_6): -0.0
# beta_0_(o_b_1,D_7): -0.0
# beta_0_(o_b_1,D_8): -0.0
# beta_0_(o_b_1,D'_9): -0.0
# beta_0_(o_b_1,D'_10): -0.0
# beta_0_(o_b_1,D'_11): -0.0
# beta_0_(o_b_1,sink): -0.0
# beta_0_(o_b_2,o_v_0): -0.0
# beta_0_(o_b_2,o_v_1): 0.0
# beta_0_(o_b_2,o_b_0): 0.0
# beta_0_(o_b_2,o_b_1): 0.0
# beta_0_(o_b_2,P_1): -0.0
# beta_0_(o_b_2,P_2): -0.0
# beta_0_(o_b_2,P'_4): -0.0
# beta_0_(o_b_2,P'_5): -0.0
# beta_0_(o_b_2,D_6): -0.0
# beta_0_(o_b_2,D_7): -0.0
# beta_0_(o_b_2,D_8): -0.0
# beta_0_(o_b_2,D'_9): -0.0
# beta_0_(o_b_2,D'_10): -0.0
# beta_0_(o_b_2,D'_11): -0.0
# beta_0_(o_b_2,sink): -0.0
# beta_0_(P_1,P'_4): -0.0
# beta_0_(P_2,P'_5): 1.0
# beta_0_(P_1,o_v_0): -0.0
# beta_0_(P_1,o_v_1): -0.0
# beta_0_(P_1,o_b_0): -0.0
# beta_0_(P_1,o_b_1): -0.0
# beta_0_(P_1,o_b_2): -0.0
# beta_0_(P_1,P_2): -0.0
# beta_0_(P_1,P'_5): -0.0
# beta_0_(P_1,D_6): -0.0
# beta_0_(P_1,D_8): -0.0
# beta_0_(P_1,D'_9): -0.0
# beta_0_(P_1,D'_11): -0.0
# beta_0_(P_1,sink): -0.0
# beta_0_(P_2,o_v_0): 0.0
# beta_0_(P_2,o_v_1): -0.0
# beta_0_(P_2,o_b_0): -0.0
# beta_0_(P_2,o_b_1): 0.0
# beta_0_(P_2,o_b_2): 0.0
# beta_0_(P_2,P_1): 0.0
# beta_0_(P_2,P'_4): 0.0
# beta_0_(P_2,D_6): -0.0
# beta_0_(P_2,D_7): -0.0
# beta_0_(P_2,D'_9): -0.0
# beta_0_(P_2,D'_10): -0.0
# beta_0_(P_2,sink): -0.0
# beta_0_(P'_4,D_6): 0.0
# beta_0_(P'_5,D_7): 0.0
# beta_0_(P'_4,o_v_0): -0.0
# beta_0_(P'_4,o_v_1): -0.0
# beta_0_(P'_4,o_b_0): -0.0
# beta_0_(P'_4,o_b_1): -0.0
# beta_0_(P'_4,o_b_2): -0.0
# beta_0_(P'_4,P_2): -0.0
# beta_0_(P'_4,P'_5): -0.0
# beta_0_(P'_4,D_6): 0.0
# beta_0_(P'_4,D_8): -0.0
# beta_0_(P'_4,D'_9): -0.0
# beta_0_(P'_4,D'_11): -0.0
# beta_0_(P'_4,sink): -0.0
# beta_0_(P'_5,o_v_0): 0.0
# beta_0_(P'_5,o_v_1): 0.0
# beta_0_(P'_5,o_b_0): 0.0
# beta_0_(P'_5,o_b_1): 0.0
# beta_0_(P'_5,o_b_2): 0.0
# beta_0_(P'_5,P_1): 0.0
# beta_0_(P'_5,P'_4): 0.0
# beta_0_(P'_5,D_6): 1.0
# beta_0_(P'_5,D_7): -0.0
# beta_0_(P'_5,D'_9): -0.0
# beta_0_(P'_5,D'_10): -0.0
# beta_0_(P'_5,sink): -0.0
# beta_0_(D_6,D'_9): 1.0
# beta_0_(D_7,D'_10): -0.0
# beta_0_(D_8,D'_11): -0.0
# beta_0_(D_6,o_v_0): 0.0
# beta_0_(D_6,o_v_1): -0.0
# beta_0_(D_6,o_b_0): -0.0
# beta_0_(D_6,o_b_1): 0.0
# beta_0_(D_6,o_b_2): 0.0
# beta_0_(D_6,P_1): 0.0
# beta_0_(D_6,P_2): -0.0
# beta_0_(D_6,P'_4): 0.0
# beta_0_(D_6,P'_5): -0.0
# beta_0_(D_6,D_7): -0.0
# beta_0_(D_6,D_8): -0.0
# beta_0_(D_6,D'_10): -0.0
# beta_0_(D_6,D'_11): -0.0
# beta_0_(D_6,sink): -0.0
# beta_0_(D_7,o_v_0): 0.0
# beta_0_(D_7,o_v_1): -0.0
# beta_0_(D_7,o_b_0): -0.0
# beta_0_(D_7,o_b_1): 0.0
# beta_0_(D_7,o_b_2): 0.0
# beta_0_(D_7,P_2): -0.0
# beta_0_(D_7,P'_5): -0.0
# beta_0_(D_7,D_6): -0.0
# beta_0_(D_7,D_8): -0.0
# beta_0_(D_7,D'_9): -0.0
# beta_0_(D_7,D'_11): -0.0
# beta_0_(D_7,sink): -0.0
# beta_0_(D_8,o_v_0): 0.0
# beta_0_(D_8,o_v_1): -0.0
# beta_0_(D_8,o_b_0): -0.0
# beta_0_(D_8,o_b_1): 0.0
# beta_0_(D_8,o_b_2): 0.0
# beta_0_(D_8,P_1): 0.0
# beta_0_(D_8,P'_4): 0.0
# beta_0_(D_8,D_6): 0.0
# beta_0_(D_8,D_7): -0.0
# beta_0_(D_8,D'_9): -0.0
# beta_0_(D_8,D'_10): -0.0
# beta_0_(D_8,sink): -0.0
# beta_0_(D'_9,o_v_0): 0.0
# beta_0_(D'_9,o_v_1): 0.0
# beta_0_(D'_9,o_b_0): -0.0
# beta_0_(D'_9,o_b_1): 0.0
# beta_0_(D'_9,o_b_2): 0.0
# beta_0_(D'_9,P_1): 0.0
# beta_0_(D'_9,P_2): 0.0
# beta_0_(D'_9,P'_4): 0.0
# beta_0_(D'_9,P'_5): 0.0
# beta_0_(D'_9,D_7): -0.0
# beta_0_(D'_9,D_8): 0.0
# beta_0_(D'_9,D'_10): -0.0
# beta_0_(D'_9,D'_11): -0.0
# beta_0_(D'_9,sink): 1.0
# beta_0_(D'_10,o_v_0): 0.0
# beta_0_(D'_10,o_v_1): -0.0
# beta_0_(D'_10,o_b_0): -0.0
# beta_0_(D'_10,o_b_1): 0.0
# beta_0_(D'_10,o_b_2): 0.0
# beta_0_(D'_10,P_2): -0.0
# beta_0_(D'_10,P'_5): -0.0
# beta_0_(D'_10,D_6): -0.0
# beta_0_(D'_10,D_8): -0.0
# beta_0_(D'_10,D'_9): -0.0
# beta_0_(D'_10,D'_11): -0.0
# beta_0_(D'_10,sink): -0.0
# beta_0_(D'_11,o_v_0): 0.0
# beta_0_(D'_11,o_v_1): -0.0
# beta_0_(D'_11,o_b_0): -0.0
# beta_0_(D'_11,o_b_1): 0.0
# beta_0_(D'_11,o_b_2): 0.0
# beta_0_(D'_11,P_1): 0.0
# beta_0_(D'_11,P'_4): 0.0
# beta_0_(D'_11,D_6): -0.0
# beta_0_(D'_11,D_7): -0.0
# beta_0_(D'_11,D'_9): -0.0
# beta_0_(D'_11,D'_10): -0.0
# beta_0_(D'_11,sink): -0.0
# beta_1_(o_v_0,o_v_1): 0.0
# beta_1_(o_v_0,o_b_0): 0.0
# beta_1_(o_v_0,o_b_1): -0.0
# beta_1_(o_v_0,o_b_2): -0.0
# beta_1_(o_v_0,P_1): 0.0
# beta_1_(o_v_0,P_2): -0.0
# beta_1_(o_v_0,P'_4): -0.0
# beta_1_(o_v_0,P'_5): -0.0
# beta_1_(o_v_0,D_6): -0.0
# beta_1_(o_v_0,D_7): -0.0
# beta_1_(o_v_0,D_8): -0.0
# beta_1_(o_v_0,D'_9): -0.0
# beta_1_(o_v_0,D'_10): -0.0
# beta_1_(o_v_0,D'_11): -0.0
# beta_1_(o_v_0,sink): -0.0
# beta_1_(o_v_1,o_v_0): 0.0
# beta_1_(o_v_1,o_b_0): -0.0
# beta_1_(o_v_1,o_b_1): 0.0
# beta_1_(o_v_1,o_b_2): 0.0
# beta_1_(o_v_1,P_1): 0.0
# beta_1_(o_v_1,P_2): -0.0
# beta_1_(o_v_1,P'_4): 0.0
# beta_1_(o_v_1,P'_5): -0.0
# beta_1_(o_v_1,D_6): -0.0
# beta_1_(o_v_1,D_7): -0.0
# beta_1_(o_v_1,D_8): 0.0
# beta_1_(o_v_1,D'_9): -0.0
# beta_1_(o_v_1,D'_10): -0.0
# beta_1_(o_v_1,D'_11): -0.0
# beta_1_(o_v_1,sink): -0.0
# beta_1_(o_b_0,o_v_0): 0.0
# beta_1_(o_b_0,o_v_1): -0.0
# beta_1_(o_b_0,o_b_1): 0.0
# beta_1_(o_b_0,o_b_2): 0.0
# beta_1_(o_b_0,P_1): 0.0
# beta_1_(o_b_0,P_2): -0.0
# beta_1_(o_b_0,P'_4): 0.0
# beta_1_(o_b_0,P'_5): -0.0
# beta_1_(o_b_0,D_6): -0.0
# beta_1_(o_b_0,D_7): -0.0
# beta_1_(o_b_0,D_8): 0.0
# beta_1_(o_b_0,D'_9): -0.0
# beta_1_(o_b_0,D'_10): -0.0
# beta_1_(o_b_0,D'_11): -0.0
# beta_1_(o_b_0,sink): -0.0
# beta_1_(o_b_1,o_v_0): 1.0
# beta_1_(o_b_1,o_v_1): -0.0
# beta_1_(o_b_1,o_b_0): -0.0
# beta_1_(o_b_1,o_b_2): -0.0
# beta_1_(o_b_1,P_1): -0.0
# beta_1_(o_b_1,P_2): -0.0
# beta_1_(o_b_1,P'_4): -0.0
# beta_1_(o_b_1,P'_5): -0.0
# beta_1_(o_b_1,D_6): -0.0
# beta_1_(o_b_1,D_7): -0.0
# beta_1_(o_b_1,D_8): -0.0
# beta_1_(o_b_1,D'_9): -0.0
# beta_1_(o_b_1,D'_10): -0.0
# beta_1_(o_b_1,D'_11): -0.0
# beta_1_(o_b_1,sink): -0.0
# beta_1_(o_b_2,o_v_0): -0.0
# beta_1_(o_b_2,o_v_1): 0.0
# beta_1_(o_b_2,o_b_0): 0.0
# beta_1_(o_b_2,o_b_1): -0.0
# beta_1_(o_b_2,P_1): -0.0
# beta_1_(o_b_2,P_2): -0.0
# beta_1_(o_b_2,P'_4): -0.0
# beta_1_(o_b_2,P'_5): -0.0
# beta_1_(o_b_2,D_6): -0.0
# beta_1_(o_b_2,D_7): -0.0
# beta_1_(o_b_2,D_8): -0.0
# beta_1_(o_b_2,D'_9): -0.0
# beta_1_(o_b_2,D'_10): -0.0
# beta_1_(o_b_2,D'_11): -0.0
# beta_1_(o_b_2,sink): 1.0
# beta_1_(P_1,P'_4): 0.0
# beta_1_(P_2,P'_5): 0.0
# beta_1_(P_1,o_v_0): -0.0
# beta_1_(P_1,o_v_1): -0.0
# beta_1_(P_1,o_b_0): -0.0
# beta_1_(P_1,o_b_1): -0.0
# beta_1_(P_1,o_b_2): -0.0
# beta_1_(P_1,P_2): -0.0
# beta_1_(P_1,P'_5): -0.0
# beta_1_(P_1,D_6): -0.0
# beta_1_(P_1,D_8): -0.0
# beta_1_(P_1,D'_9): -0.0
# beta_1_(P_1,D'_11): -0.0
# beta_1_(P_1,sink): -0.0
# beta_1_(P_2,o_v_0): 0.0
# beta_1_(P_2,o_v_1): -0.0
# beta_1_(P_2,o_b_0): -0.0
# beta_1_(P_2,o_b_1): 0.0
# beta_1_(P_2,o_b_2): 0.0
# beta_1_(P_2,P_1): 0.0
# beta_1_(P_2,P'_4): 0.0
# beta_1_(P_2,D_6): -0.0
# beta_1_(P_2,D_7): -0.0
# beta_1_(P_2,D'_9): -0.0
# beta_1_(P_2,D'_10): -0.0
# beta_1_(P_2,sink): -0.0
# beta_1_(P'_4,D_6): 0.0
# beta_1_(P'_5,D_7): 0.0
# beta_1_(P'_4,o_v_0): -0.0
# beta_1_(P'_4,o_v_1): -0.0
# beta_1_(P'_4,o_b_0): -0.0
# beta_1_(P'_4,o_b_1): -0.0
# beta_1_(P'_4,o_b_2): 0.0
# beta_1_(P'_4,P_2): -0.0
# beta_1_(P'_4,P'_5): -0.0
# beta_1_(P'_4,D_6): 0.0
# beta_1_(P'_4,D_8): -0.0
# beta_1_(P'_4,D'_9): -0.0
# beta_1_(P'_4,D'_11): -0.0
# beta_1_(P'_4,sink): -0.0
# beta_1_(P'_5,o_v_0): 0.0
# beta_1_(P'_5,o_v_1): 0.0
# beta_1_(P'_5,o_b_0): 0.0
# beta_1_(P'_5,o_b_1): 0.0
# beta_1_(P'_5,o_b_2): 0.0
# beta_1_(P'_5,P_1): 0.0
# beta_1_(P'_5,P'_4): 0.0
# beta_1_(P'_5,D_6): -0.0
# beta_1_(P'_5,D_7): -0.0
# beta_1_(P'_5,D'_9): -0.0
# beta_1_(P'_5,D'_10): -0.0
# beta_1_(P'_5,sink): -0.0
# beta_1_(D_6,D'_9): -0.0
# beta_1_(D_7,D'_10): -0.0
# beta_1_(D_8,D'_11): -0.0
# beta_1_(D_6,o_v_0): 0.0
# beta_1_(D_6,o_v_1): -0.0
# beta_1_(D_6,o_b_0): 0.0
# beta_1_(D_6,o_b_1): 0.0
# beta_1_(D_6,o_b_2): 0.0
# beta_1_(D_6,P_1): 0.0
# beta_1_(D_6,P_2): 0.0
# beta_1_(D_6,P'_4): 0.0
# beta_1_(D_6,P'_5): -0.0
# beta_1_(D_6,D_7): -0.0
# beta_1_(D_6,D_8): -0.0
# beta_1_(D_6,D'_10): -0.0
# beta_1_(D_6,D'_11): -0.0
# beta_1_(D_6,sink): -0.0
# beta_1_(D_7,o_v_0): 0.0
# beta_1_(D_7,o_v_1): -0.0
# beta_1_(D_7,o_b_0): -0.0
# beta_1_(D_7,o_b_1): 0.0
# beta_1_(D_7,o_b_2): 0.0
# beta_1_(D_7,P_2): -0.0
# beta_1_(D_7,P'_5): -0.0
# beta_1_(D_7,D_6): -0.0
# beta_1_(D_7,D_8): -0.0
# beta_1_(D_7,D'_9): -0.0
# beta_1_(D_7,D'_11): -0.0
# beta_1_(D_7,sink): -0.0
# beta_1_(D_8,o_v_0): 0.0
# beta_1_(D_8,o_v_1): -0.0
# beta_1_(D_8,o_b_0): -0.0
# beta_1_(D_8,o_b_1): 0.0
# beta_1_(D_8,o_b_2): 0.0
# beta_1_(D_8,P_1): 0.0
# beta_1_(D_8,P'_4): 0.0
# beta_1_(D_8,D_6): 0.0
# beta_1_(D_8,D_7): -0.0
# beta_1_(D_8,D'_9): -0.0
# beta_1_(D_8,D'_10): -0.0
# beta_1_(D_8,sink): -0.0
# beta_1_(D'_9,o_v_0): 0.0
# beta_1_(D'_9,o_v_1): -0.0
# beta_1_(D'_9,o_b_0): -0.0
# beta_1_(D'_9,o_b_1): 0.0
# beta_1_(D'_9,o_b_2): 0.0
# beta_1_(D'_9,P_1): 0.0
# beta_1_(D'_9,P_2): -0.0
# beta_1_(D'_9,P'_4): 0.0
# beta_1_(D'_9,P'_5): -0.0
# beta_1_(D'_9,D_7): -0.0
# beta_1_(D'_9,D_8): -0.0
# beta_1_(D'_9,D'_10): -0.0
# beta_1_(D'_9,D'_11): -0.0
# beta_1_(D'_9,sink): -0.0
# beta_1_(D'_10,o_v_0): 0.0
# beta_1_(D'_10,o_v_1): -0.0
# beta_1_(D'_10,o_b_0): -0.0
# beta_1_(D'_10,o_b_1): 0.0
# beta_1_(D'_10,o_b_2): 0.0
# beta_1_(D'_10,P_2): -0.0
# beta_1_(D'_10,P'_5): -0.0
# beta_1_(D'_10,D_6): -0.0
# beta_1_(D'_10,D_8): -0.0
# beta_1_(D'_10,D'_9): -0.0
# beta_1_(D'_10,D'_11): -0.0
# beta_1_(D'_10,sink): -0.0
# beta_1_(D'_11,o_v_0): 0.0
# beta_1_(D'_11,o_v_1): -0.0
# beta_1_(D'_11,o_b_0): -0.0
# beta_1_(D'_11,o_b_1): 0.0
# beta_1_(D'_11,o_b_2): 0.0
# beta_1_(D'_11,P_1): 0.0
# beta_1_(D'_11,P'_4): 0.0
# beta_1_(D'_11,D_6): -0.0
# beta_1_(D'_11,D_7): -0.0
# beta_1_(D'_11,D'_9): -0.0
# beta_1_(D'_11,D'_10): -0.0
# beta_1_(D'_11,sink): -0.0
# beta_2_(o_v_0,o_v_1): 0.0
# beta_2_(o_v_0,o_b_0): 0.0
# beta_2_(o_v_0,o_b_1): 0.0
# beta_2_(o_v_0,o_b_2): 0.0
# beta_2_(o_v_0,P_1): -0.0
# beta_2_(o_v_0,P_2): 1.0
# beta_2_(o_v_0,P'_4): -0.0
# beta_2_(o_v_0,P'_5): 0.0
# beta_2_(o_v_0,D_6): 0.0
# beta_2_(o_v_0,D_7): 0.0
# beta_2_(o_v_0,D_8): 0.0
# beta_2_(o_v_0,D'_9): 0.0
# beta_2_(o_v_0,D'_10): 0.0
# beta_2_(o_v_0,D'_11): 0.0
# beta_2_(o_v_0,sink): -0.0
# beta_2_(o_v_1,o_v_0): 0.0
# beta_2_(o_v_1,o_b_0): 0.0
# beta_2_(o_v_1,o_b_1): 0.0
# beta_2_(o_v_1,o_b_2): 0.0
# beta_2_(o_v_1,P_1): 0.0
# beta_2_(o_v_1,P_2): 0.0
# beta_2_(o_v_1,P'_4): 0.0
# beta_2_(o_v_1,P'_5): 0.0
# beta_2_(o_v_1,D_6): 0.0
# beta_2_(o_v_1,D_7): 0.0
# beta_2_(o_v_1,D_8): 0.0
# beta_2_(o_v_1,D'_9): 0.0
# beta_2_(o_v_1,D'_10): -0.0
# beta_2_(o_v_1,D'_11): 0.0
# beta_2_(o_v_1,sink): -0.0
# beta_2_(o_b_0,o_v_0): 0.0
# beta_2_(o_b_0,o_v_1): 1.0
# beta_2_(o_b_0,o_b_1): 0.0
# beta_2_(o_b_0,o_b_2): 0.0
# beta_2_(o_b_0,P_1): 0.0
# beta_2_(o_b_0,P_2): 0.0
# beta_2_(o_b_0,P'_4): 0.0
# beta_2_(o_b_0,P'_5): 0.0
# beta_2_(o_b_0,D_6): 0.0
# beta_2_(o_b_0,D_7): 1.0
# beta_2_(o_b_0,D_8): 1.0
# beta_2_(o_b_0,D'_9): 0.0
# beta_2_(o_b_0,D'_10): -0.0
# beta_2_(o_b_0,D'_11): 0.0
# beta_2_(o_b_0,sink): -0.0
# beta_2_(o_b_1,o_v_0): 1.0
# beta_2_(o_b_1,o_v_1): 0.0
# beta_2_(o_b_1,o_b_0): 0.0
# beta_2_(o_b_1,o_b_2): 0.0
# beta_2_(o_b_1,P_1): -0.0
# beta_2_(o_b_1,P_2): 0.0
# beta_2_(o_b_1,P'_4): -0.0
# beta_2_(o_b_1,P'_5): 0.0
# beta_2_(o_b_1,D_6): 0.0
# beta_2_(o_b_1,D_7): 0.0
# beta_2_(o_b_1,D_8): 0.0
# beta_2_(o_b_1,D'_9): 0.0
# beta_2_(o_b_1,D'_10): 0.0
# beta_2_(o_b_1,D'_11): 0.0
# beta_2_(o_b_1,sink): 0.0
# beta_2_(o_b_2,o_v_0): -0.0
# beta_2_(o_b_2,o_v_1): 0.0
# beta_2_(o_b_2,o_b_0): 0.0
# beta_2_(o_b_2,o_b_1): -0.0
# beta_2_(o_b_2,P_1): 1.0
# beta_2_(o_b_2,P_2): -0.0
# beta_2_(o_b_2,P'_4): -0.0
# beta_2_(o_b_2,P'_5): -0.0
# beta_2_(o_b_2,D_6): -0.0
# beta_2_(o_b_2,D_7): -0.0
# beta_2_(o_b_2,D_8): -0.0
# beta_2_(o_b_2,D'_9): -0.0
# beta_2_(o_b_2,D'_10): -0.0
# beta_2_(o_b_2,D'_11): -0.0
# beta_2_(o_b_2,sink): -0.0
# beta_2_(P_1,P'_4): 1.0
# beta_2_(P_2,P'_5): 1.0
# beta_2_(P_1,o_v_0): -0.0
# beta_2_(P_1,o_v_1): 0.0
# beta_2_(P_1,o_b_0): 0.0
# beta_2_(P_1,o_b_1): -0.0
# beta_2_(P_1,o_b_2): -0.0
# beta_2_(P_1,P_2): -0.0
# beta_2_(P_1,P'_5): -0.0
# beta_2_(P_1,D_6): -0.0
# beta_2_(P_1,D_8): -0.0
# beta_2_(P_1,D'_9): -0.0
# beta_2_(P_1,D'_11): -0.0
# beta_2_(P_1,sink): -0.0
# beta_2_(P_2,o_v_0): 0.0
# beta_2_(P_2,o_v_1): 0.0
# beta_2_(P_2,o_b_0): 0.0
# beta_2_(P_2,o_b_1): 0.0
# beta_2_(P_2,o_b_2): 0.0
# beta_2_(P_2,P_1): 0.0
# beta_2_(P_2,P'_4): 0.0
# beta_2_(P_2,D_6): 0.0
# beta_2_(P_2,D_7): -0.0
# beta_2_(P_2,D'_9): -0.0
# beta_2_(P_2,D'_10): -0.0
# beta_2_(P_2,sink): -0.0
# beta_2_(P'_4,D_6): 0.0
# beta_2_(P'_5,D_7): 0.0
# beta_2_(P'_4,o_v_0): 1.0
# beta_2_(P'_4,o_v_1): 0.0
# beta_2_(P'_4,o_b_0): 0.0
# beta_2_(P'_4,o_b_1): -0.0
# beta_2_(P'_4,o_b_2): -0.0
# beta_2_(P'_4,P_2): -0.0
# beta_2_(P'_4,P'_5): -0.0
# beta_2_(P'_4,D_6): 0.0
# beta_2_(P'_4,D_8): -0.0
# beta_2_(P'_4,D'_9): -0.0
# beta_2_(P'_4,D'_11): -0.0
# beta_2_(P'_4,sink): -0.0
# beta_2_(P'_5,o_v_0): 0.0
# beta_2_(P'_5,o_v_1): 0.0
# beta_2_(P'_5,o_b_0): 1.0
# beta_2_(P'_5,o_b_1): 0.0
# beta_2_(P'_5,o_b_2): 0.0
# beta_2_(P'_5,P_1): 0.0
# beta_2_(P'_5,P'_4): 0.0
# beta_2_(P'_5,D_6): 0.0
# beta_2_(P'_5,D_7): 0.0
# beta_2_(P'_5,D'_9): 0.0
# beta_2_(P'_5,D'_10): -0.0
# beta_2_(P'_5,sink): -0.0
# beta_2_(D_6,D'_9): -0.0
# beta_2_(D_7,D'_10): 1.0
# beta_2_(D_8,D'_11): 1.0
# beta_2_(D_6,o_v_0): 0.0
# beta_2_(D_6,o_v_1): 0.0
# beta_2_(D_6,o_b_0): 0.0
# beta_2_(D_6,o_b_1): 0.0
# beta_2_(D_6,o_b_2): 0.0
# beta_2_(D_6,P_1): 0.0
# beta_2_(D_6,P_2): 0.0
# beta_2_(D_6,P'_4): 0.0
# beta_2_(D_6,P'_5): -0.0
# beta_2_(D_6,D_7): 0.0
# beta_2_(D_6,D_8): -0.0
# beta_2_(D_6,D'_10): -0.0
# beta_2_(D_6,D'_11): -0.0
# beta_2_(D_6,sink): -0.0
# beta_2_(D_7,o_v_0): 0.0
# beta_2_(D_7,o_v_1): -0.0
# beta_2_(D_7,o_b_0): -0.0
# beta_2_(D_7,o_b_1): 0.0
# beta_2_(D_7,o_b_2): 0.0
# beta_2_(D_7,P_2): 0.0
# beta_2_(D_7,P'_5): -0.0
# beta_2_(D_7,D_6): -0.0
# beta_2_(D_7,D_8): -0.0
# beta_2_(D_7,D'_9): -0.0
# beta_2_(D_7,D'_11): -0.0
# beta_2_(D_7,sink): -0.0
# beta_2_(D_8,o_v_0): 0.0
# beta_2_(D_8,o_v_1): 0.0
# beta_2_(D_8,o_b_0): 0.0
# beta_2_(D_8,o_b_1): 0.0
# beta_2_(D_8,o_b_2): 0.0
# beta_2_(D_8,P_1): 0.0
# beta_2_(D_8,P'_4): 0.0
# beta_2_(D_8,D_6): -0.0
# beta_2_(D_8,D_7): 0.0
# beta_2_(D_8,D'_9): -0.0
# beta_2_(D_8,D'_10): -0.0
# beta_2_(D_8,sink): -0.0
# beta_2_(D'_9,o_v_0): 0.0
# beta_2_(D'_9,o_v_1): 0.0
# beta_2_(D'_9,o_b_0): 0.0
# beta_2_(D'_9,o_b_1): 0.0
# beta_2_(D'_9,o_b_2): 0.0
# beta_2_(D'_9,P_1): 0.0
# beta_2_(D'_9,P_2): -0.0
# beta_2_(D'_9,P'_4): 0.0
# beta_2_(D'_9,P'_5): -0.0
# beta_2_(D'_9,D_7): -0.0
# beta_2_(D'_9,D_8): 0.0
# beta_2_(D'_9,D'_10): -0.0
# beta_2_(D'_9,D'_11): -0.0
# beta_2_(D'_9,sink): -0.0
# beta_2_(D'_10,o_v_0): 0.0
# beta_2_(D'_10,o_v_1): 1.0
# beta_2_(D'_10,o_b_0): 0.0
# beta_2_(D'_10,o_b_1): 0.0
# beta_2_(D'_10,o_b_2): 0.0
# beta_2_(D'_10,P_2): 0.0
# beta_2_(D'_10,P'_5): -0.0
# beta_2_(D'_10,D_6): -0.0
# beta_2_(D'_10,D_8): -0.0
# beta_2_(D'_10,D'_9): -0.0
# beta_2_(D'_10,D'_11): -0.0
# beta_2_(D'_10,sink): 0.0
# beta_2_(D'_11,o_v_0): 0.0
# beta_2_(D'_11,o_v_1): 0.0
# beta_2_(D'_11,o_b_0): 0.0
# beta_2_(D'_11,o_b_1): 0.0
# beta_2_(D'_11,o_b_2): 0.0
# beta_2_(D'_11,P_1): 0.0
# beta_2_(D'_11,P'_4): 0.0
# beta_2_(D'_11,D_6): -0.0
# beta_2_(D'_11,D_7): -0.0
# beta_2_(D'_11,D'_9): 0.0
# beta_2_(D'_11,D'_10): -0.0
# beta_2_(D'_11,sink): 1.0
# omega_0_0_(o_v_0,o_v_1): -0.0
# omega_0_0_(o_v_0,o_b_0): -0.0
# omega_0_0_(o_v_0,o_b_1): -0.0
# omega_0_0_(o_v_0,o_b_2): -0.0
# omega_0_0_(o_v_0,P_1): -0.0
# omega_0_0_(o_v_0,P_2): -0.0
# omega_0_0_(o_v_0,P'_4): -0.0
# omega_0_0_(o_v_0,P'_5): -0.0
# omega_0_0_(o_v_0,D_6): -0.0
# omega_0_0_(o_v_0,D_7): -0.0
# omega_0_0_(o_v_0,D_8): -0.0
# omega_0_0_(o_v_0,D'_9): -0.0
# omega_0_0_(o_v_0,D'_10): -0.0
# omega_0_0_(o_v_0,D'_11): -0.0
# omega_0_0_(o_v_0,sink): -0.0
# omega_0_0_(o_v_1,o_v_0): 0.0
# omega_0_0_(o_v_1,o_b_0): -0.0
# omega_0_0_(o_v_1,o_b_1): 0.0
# omega_0_0_(o_v_1,o_b_2): 0.0
# omega_0_0_(o_v_1,P_1): 0.0
# omega_0_0_(o_v_1,P_2): -0.0
# omega_0_0_(o_v_1,P'_4): 0.0
# omega_0_0_(o_v_1,P'_5): -0.0
# omega_0_0_(o_v_1,D_6): -0.0
# omega_0_0_(o_v_1,D_7): -0.0
# omega_0_0_(o_v_1,D_8): -0.0
# omega_0_0_(o_v_1,D'_9): -0.0
# omega_0_0_(o_v_1,D'_10): -0.0
# omega_0_0_(o_v_1,D'_11): -0.0
# omega_0_0_(o_v_1,sink): -0.0
# omega_0_0_(o_b_0,o_v_0): 0.0
# omega_0_0_(o_b_0,o_v_1): -0.0
# omega_0_0_(o_b_0,o_b_1): 0.0
# omega_0_0_(o_b_0,o_b_2): 0.0
# omega_0_0_(o_b_0,P_1): 0.0
# omega_0_0_(o_b_0,P_2): -0.0
# omega_0_0_(o_b_0,P'_4): 0.0
# omega_0_0_(o_b_0,P'_5): -0.0
# omega_0_0_(o_b_0,D_6): -0.0
# omega_0_0_(o_b_0,D_7): -0.0
# omega_0_0_(o_b_0,D_8): -0.0
# omega_0_0_(o_b_0,D'_9): -0.0
# omega_0_0_(o_b_0,D'_10): -0.0
# omega_0_0_(o_b_0,D'_11): -0.0
# omega_0_0_(o_b_0,sink): 0.0
# omega_0_0_(o_b_1,o_v_0): -0.0
# omega_0_0_(o_b_1,o_v_1): -0.0
# omega_0_0_(o_b_1,o_b_0): -0.0
# omega_0_0_(o_b_1,o_b_2): -0.0
# omega_0_0_(o_b_1,P_1): -0.0
# omega_0_0_(o_b_1,P_2): -0.0
# omega_0_0_(o_b_1,P'_4): -0.0
# omega_0_0_(o_b_1,P'_5): -0.0
# omega_0_0_(o_b_1,D_6): -0.0
# omega_0_0_(o_b_1,D_7): -0.0
# omega_0_0_(o_b_1,D_8): -0.0
# omega_0_0_(o_b_1,D'_9): -0.0
# omega_0_0_(o_b_1,D'_10): -0.0
# omega_0_0_(o_b_1,D'_11): -0.0
# omega_0_0_(o_b_1,sink): -0.0
# omega_0_0_(o_b_2,o_v_0): -0.0
# omega_0_0_(o_b_2,o_v_1): -0.0
# omega_0_0_(o_b_2,o_b_0): -0.0
# omega_0_0_(o_b_2,o_b_1): -0.0
# omega_0_0_(o_b_2,P_1): -0.0
# omega_0_0_(o_b_2,P_2): -0.0
# omega_0_0_(o_b_2,P'_4): -0.0
# omega_0_0_(o_b_2,P'_5): -0.0
# omega_0_0_(o_b_2,D_6): -0.0
# omega_0_0_(o_b_2,D_7): -0.0
# omega_0_0_(o_b_2,D_8): -0.0
# omega_0_0_(o_b_2,D'_9): -0.0
# omega_0_0_(o_b_2,D'_10): -0.0
# omega_0_0_(o_b_2,D'_11): -0.0
# omega_0_0_(o_b_2,sink): -0.0
# omega_0_0_(P_1,P'_4): -0.0
# omega_0_0_(P_2,P'_5): -0.0
# omega_0_0_(P_1,o_v_0): -0.0
# omega_0_0_(P_1,o_v_1): -0.0
# omega_0_0_(P_1,o_b_0): -0.0
# omega_0_0_(P_1,o_b_1): -0.0
# omega_0_0_(P_1,o_b_2): -0.0
# omega_0_0_(P_1,P_2): -0.0
# omega_0_0_(P_1,P'_5): -0.0
# omega_0_0_(P_1,D_6): -0.0
# omega_0_0_(P_1,D_8): -0.0
# omega_0_0_(P_1,D'_9): -0.0
# omega_0_0_(P_1,D'_11): -0.0
# omega_0_0_(P_1,sink): -0.0
# omega_0_0_(P_2,o_v_0): 0.0
# omega_0_0_(P_2,o_v_1): -0.0
# omega_0_0_(P_2,o_b_0): -0.0
# omega_0_0_(P_2,o_b_1): 0.0
# omega_0_0_(P_2,o_b_2): 0.0
# omega_0_0_(P_2,P_1): 0.0
# omega_0_0_(P_2,P'_4): 0.0
# omega_0_0_(P_2,D_6): -0.0
# omega_0_0_(P_2,D_7): -0.0
# omega_0_0_(P_2,D'_9): -0.0
# omega_0_0_(P_2,D'_10): -0.0
# omega_0_0_(P_2,sink): -0.0
# omega_0_0_(P'_4,D_6): 0.0
# omega_0_0_(P'_5,D_7): 0.0
# omega_0_0_(P'_4,o_v_0): -0.0
# omega_0_0_(P'_4,o_v_1): -0.0
# omega_0_0_(P'_4,o_b_0): -0.0
# omega_0_0_(P'_4,o_b_1): -0.0
# omega_0_0_(P'_4,o_b_2): -0.0
# omega_0_0_(P'_4,P_2): -0.0
# omega_0_0_(P'_4,P'_5): -0.0
# omega_0_0_(P'_4,D_6): 0.0
# omega_0_0_(P'_4,D_8): -0.0
# omega_0_0_(P'_4,D'_9): -0.0
# omega_0_0_(P'_4,D'_11): -0.0
# omega_0_0_(P'_4,sink): -0.0
# omega_0_0_(P'_5,o_v_0): 0.0
# omega_0_0_(P'_5,o_v_1): -0.0
# omega_0_0_(P'_5,o_b_0): -0.0
# omega_0_0_(P'_5,o_b_1): 0.0
# omega_0_0_(P'_5,o_b_2): 0.0
# omega_0_0_(P'_5,P_1): 0.0
# omega_0_0_(P'_5,P'_4): 0.0
# omega_0_0_(P'_5,D_6): -0.0
# omega_0_0_(P'_5,D_7): -0.0
# omega_0_0_(P'_5,D'_9): -0.0
# omega_0_0_(P'_5,D'_10): -0.0
# omega_0_0_(P'_5,sink): -0.0
# omega_0_0_(D_6,D'_9): -0.0
# omega_0_0_(D_7,D'_10): -0.0
# omega_0_0_(D_8,D'_11): -0.0
# omega_0_0_(D_6,o_v_0): 0.0
# omega_0_0_(D_6,o_v_1): -0.0
# omega_0_0_(D_6,o_b_0): -0.0
# omega_0_0_(D_6,o_b_1): 0.0
# omega_0_0_(D_6,o_b_2): 0.0
# omega_0_0_(D_6,P_1): 0.0
# omega_0_0_(D_6,P_2): -0.0
# omega_0_0_(D_6,P'_4): 0.0
# omega_0_0_(D_6,P'_5): -0.0
# omega_0_0_(D_6,D_7): -0.0
# omega_0_0_(D_6,D_8): -0.0
# omega_0_0_(D_6,D'_10): -0.0
# omega_0_0_(D_6,D'_11): -0.0
# omega_0_0_(D_6,sink): -0.0
# omega_0_0_(D_7,o_v_0): 0.0
# omega_0_0_(D_7,o_v_1): -0.0
# omega_0_0_(D_7,o_b_0): -0.0
# omega_0_0_(D_7,o_b_1): 0.0
# omega_0_0_(D_7,o_b_2): 0.0
# omega_0_0_(D_7,P_2): -0.0
# omega_0_0_(D_7,P'_5): -0.0
# omega_0_0_(D_7,D_6): -0.0
# omega_0_0_(D_7,D_8): -0.0
# omega_0_0_(D_7,D'_9): -0.0
# omega_0_0_(D_7,D'_11): -0.0
# omega_0_0_(D_7,sink): -0.0
# omega_0_0_(D_8,o_v_0): 0.0
# omega_0_0_(D_8,o_v_1): -0.0
# omega_0_0_(D_8,o_b_0): -0.0
# omega_0_0_(D_8,o_b_1): 0.0
# omega_0_0_(D_8,o_b_2): 0.0
# omega_0_0_(D_8,P_1): 0.0
# omega_0_0_(D_8,P'_4): 0.0
# omega_0_0_(D_8,D_6): 0.0
# omega_0_0_(D_8,D_7): -0.0
# omega_0_0_(D_8,D'_9): -0.0
# omega_0_0_(D_8,D'_10): -0.0
# omega_0_0_(D_8,sink): -0.0
# omega_0_0_(D'_9,o_v_0): 0.0
# omega_0_0_(D'_9,o_v_1): -0.0
# omega_0_0_(D'_9,o_b_0): -0.0
# omega_0_0_(D'_9,o_b_1): 0.0
# omega_0_0_(D'_9,o_b_2): 0.0
# omega_0_0_(D'_9,P_1): 0.0
# omega_0_0_(D'_9,P_2): -0.0
# omega_0_0_(D'_9,P'_4): 0.0
# omega_0_0_(D'_9,P'_5): -0.0
# omega_0_0_(D'_9,D_7): -0.0
# omega_0_0_(D'_9,D_8): -0.0
# omega_0_0_(D'_9,D'_10): -0.0
# omega_0_0_(D'_9,D'_11): -0.0
# omega_0_0_(D'_9,sink): -0.0
# omega_0_0_(D'_10,o_v_0): 0.0
# omega_0_0_(D'_10,o_v_1): -0.0
# omega_0_0_(D'_10,o_b_0): -0.0
# omega_0_0_(D'_10,o_b_1): 0.0
# omega_0_0_(D'_10,o_b_2): 0.0
# omega_0_0_(D'_10,P_2): -0.0
# omega_0_0_(D'_10,P'_5): -0.0
# omega_0_0_(D'_10,D_6): -0.0
# omega_0_0_(D'_10,D_8): -0.0
# omega_0_0_(D'_10,D'_9): -0.0
# omega_0_0_(D'_10,D'_11): -0.0
# omega_0_0_(D'_10,sink): -0.0
# omega_0_0_(D'_11,o_v_0): 0.0
# omega_0_0_(D'_11,o_v_1): -0.0
# omega_0_0_(D'_11,o_b_0): -0.0
# omega_0_0_(D'_11,o_b_1): 0.0
# omega_0_0_(D'_11,o_b_2): 0.0
# omega_0_0_(D'_11,P_1): 0.0
# omega_0_0_(D'_11,P'_4): 0.0
# omega_0_0_(D'_11,D_6): -0.0
# omega_0_0_(D'_11,D_7): -0.0
# omega_0_0_(D'_11,D'_9): -0.0
# omega_0_0_(D'_11,D'_10): -0.0
# omega_0_0_(D'_11,sink): -0.0
# omega_1_0_(o_v_0,o_v_1): -0.0
# omega_1_0_(o_v_0,o_b_0): -0.0
# omega_1_0_(o_v_0,o_b_1): -0.0
# omega_1_0_(o_v_0,o_b_2): -0.0
# omega_1_0_(o_v_0,P_1): -0.0
# omega_1_0_(o_v_0,P_2): -0.0
# omega_1_0_(o_v_0,P'_4): -0.0
# omega_1_0_(o_v_0,P'_5): -0.0
# omega_1_0_(o_v_0,D_6): -0.0
# omega_1_0_(o_v_0,D_7): -0.0
# omega_1_0_(o_v_0,D_8): -0.0
# omega_1_0_(o_v_0,D'_9): -0.0
# omega_1_0_(o_v_0,D'_10): -0.0
# omega_1_0_(o_v_0,D'_11): -0.0
# omega_1_0_(o_v_0,sink): -0.0
# omega_1_0_(o_v_1,o_v_0): 0.0
# omega_1_0_(o_v_1,o_b_0): -0.0
# omega_1_0_(o_v_1,o_b_1): 0.0
# omega_1_0_(o_v_1,o_b_2): 0.0
# omega_1_0_(o_v_1,P_1): 0.0
# omega_1_0_(o_v_1,P_2): -0.0
# omega_1_0_(o_v_1,P'_4): 0.0
# omega_1_0_(o_v_1,P'_5): -0.0
# omega_1_0_(o_v_1,D_6): -0.0
# omega_1_0_(o_v_1,D_7): -0.0
# omega_1_0_(o_v_1,D_8): -0.0
# omega_1_0_(o_v_1,D'_9): -0.0
# omega_1_0_(o_v_1,D'_10): -0.0
# omega_1_0_(o_v_1,D'_11): -0.0
# omega_1_0_(o_v_1,sink): -0.0
# omega_1_0_(o_b_0,o_v_0): 0.0
# omega_1_0_(o_b_0,o_v_1): -0.0
# omega_1_0_(o_b_0,o_b_1): 0.0
# omega_1_0_(o_b_0,o_b_2): 0.0
# omega_1_0_(o_b_0,P_1): 0.0
# omega_1_0_(o_b_0,P_2): -0.0
# omega_1_0_(o_b_0,P'_4): 0.0
# omega_1_0_(o_b_0,P'_5): -0.0
# omega_1_0_(o_b_0,D_6): -0.0
# omega_1_0_(o_b_0,D_7): -0.0
# omega_1_0_(o_b_0,D_8): -0.0
# omega_1_0_(o_b_0,D'_9): -0.0
# omega_1_0_(o_b_0,D'_10): -0.0
# omega_1_0_(o_b_0,D'_11): -0.0
# omega_1_0_(o_b_0,sink): -0.0
# omega_1_0_(o_b_1,o_v_0): -0.0
# omega_1_0_(o_b_1,o_v_1): -0.0
# omega_1_0_(o_b_1,o_b_0): -0.0
# omega_1_0_(o_b_1,o_b_2): -0.0
# omega_1_0_(o_b_1,P_1): -0.0
# omega_1_0_(o_b_1,P_2): -0.0
# omega_1_0_(o_b_1,P'_4): -0.0
# omega_1_0_(o_b_1,P'_5): -0.0
# omega_1_0_(o_b_1,D_6): -0.0
# omega_1_0_(o_b_1,D_7): -0.0
# omega_1_0_(o_b_1,D_8): -0.0
# omega_1_0_(o_b_1,D'_9): -0.0
# omega_1_0_(o_b_1,D'_10): -0.0
# omega_1_0_(o_b_1,D'_11): -0.0
# omega_1_0_(o_b_1,sink): 0.0
# omega_1_0_(o_b_2,o_v_0): -0.0
# omega_1_0_(o_b_2,o_v_1): -0.0
# omega_1_0_(o_b_2,o_b_0): -0.0
# omega_1_0_(o_b_2,o_b_1): -0.0
# omega_1_0_(o_b_2,P_1): -0.0
# omega_1_0_(o_b_2,P_2): -0.0
# omega_1_0_(o_b_2,P'_4): -0.0
# omega_1_0_(o_b_2,P'_5): -0.0
# omega_1_0_(o_b_2,D_6): -0.0
# omega_1_0_(o_b_2,D_7): -0.0
# omega_1_0_(o_b_2,D_8): -0.0
# omega_1_0_(o_b_2,D'_9): -0.0
# omega_1_0_(o_b_2,D'_10): -0.0
# omega_1_0_(o_b_2,D'_11): -0.0
# omega_1_0_(o_b_2,sink): -0.0
# omega_1_0_(P_1,P'_4): -0.0
# omega_1_0_(P_2,P'_5): -0.0
# omega_1_0_(P_1,o_v_0): -0.0
# omega_1_0_(P_1,o_v_1): -0.0
# omega_1_0_(P_1,o_b_0): -0.0
# omega_1_0_(P_1,o_b_1): -0.0
# omega_1_0_(P_1,o_b_2): -0.0
# omega_1_0_(P_1,P_2): -0.0
# omega_1_0_(P_1,P'_5): -0.0
# omega_1_0_(P_1,D_6): -0.0
# omega_1_0_(P_1,D_8): -0.0
# omega_1_0_(P_1,D'_9): -0.0
# omega_1_0_(P_1,D'_11): -0.0
# omega_1_0_(P_1,sink): -0.0
# omega_1_0_(P_2,o_v_0): 0.0
# omega_1_0_(P_2,o_v_1): -0.0
# omega_1_0_(P_2,o_b_0): -0.0
# omega_1_0_(P_2,o_b_1): 0.0
# omega_1_0_(P_2,o_b_2): 0.0
# omega_1_0_(P_2,P_1): 0.0
# omega_1_0_(P_2,P'_4): 0.0
# omega_1_0_(P_2,D_6): -0.0
# omega_1_0_(P_2,D_7): -0.0
# omega_1_0_(P_2,D'_9): -0.0
# omega_1_0_(P_2,D'_10): -0.0
# omega_1_0_(P_2,sink): -0.0
# omega_1_0_(P'_4,D_6): 0.0
# omega_1_0_(P'_5,D_7): 0.0
# omega_1_0_(P'_4,o_v_0): -0.0
# omega_1_0_(P'_4,o_v_1): -0.0
# omega_1_0_(P'_4,o_b_0): -0.0
# omega_1_0_(P'_4,o_b_1): -0.0
# omega_1_0_(P'_4,o_b_2): -0.0
# omega_1_0_(P'_4,P_2): -0.0
# omega_1_0_(P'_4,P'_5): -0.0
# omega_1_0_(P'_4,D_6): 0.0
# omega_1_0_(P'_4,D_8): -0.0
# omega_1_0_(P'_4,D'_9): -0.0
# omega_1_0_(P'_4,D'_11): -0.0
# omega_1_0_(P'_4,sink): -0.0
# omega_1_0_(P'_5,o_v_0): 0.0
# omega_1_0_(P'_5,o_v_1): -0.0
# omega_1_0_(P'_5,o_b_0): -0.0
# omega_1_0_(P'_5,o_b_1): 0.0
# omega_1_0_(P'_5,o_b_2): 0.0
# omega_1_0_(P'_5,P_1): 0.0
# omega_1_0_(P'_5,P'_4): 0.0
# omega_1_0_(P'_5,D_6): -0.0
# omega_1_0_(P'_5,D_7): -0.0
# omega_1_0_(P'_5,D'_9): -0.0
# omega_1_0_(P'_5,D'_10): -0.0
# omega_1_0_(P'_5,sink): -0.0
# omega_1_0_(D_6,D'_9): -0.0
# omega_1_0_(D_7,D'_10): -0.0
# omega_1_0_(D_8,D'_11): -0.0
# omega_1_0_(D_6,o_v_0): 0.0
# omega_1_0_(D_6,o_v_1): -0.0
# omega_1_0_(D_6,o_b_0): 0.0
# omega_1_0_(D_6,o_b_1): 0.0
# omega_1_0_(D_6,o_b_2): 0.0
# omega_1_0_(D_6,P_1): 0.0
# omega_1_0_(D_6,P_2): -0.0
# omega_1_0_(D_6,P'_4): 0.0
# omega_1_0_(D_6,P'_5): -0.0
# omega_1_0_(D_6,D_7): -0.0
# omega_1_0_(D_6,D_8): -0.0
# omega_1_0_(D_6,D'_10): -0.0
# omega_1_0_(D_6,D'_11): -0.0
# omega_1_0_(D_6,sink): -0.0
# omega_1_0_(D_7,o_v_0): 0.0
# omega_1_0_(D_7,o_v_1): -0.0
# omega_1_0_(D_7,o_b_0): -0.0
# omega_1_0_(D_7,o_b_1): 0.0
# omega_1_0_(D_7,o_b_2): 0.0
# omega_1_0_(D_7,P_2): -0.0
# omega_1_0_(D_7,P'_5): -0.0
# omega_1_0_(D_7,D_6): -0.0
# omega_1_0_(D_7,D_8): -0.0
# omega_1_0_(D_7,D'_9): -0.0
# omega_1_0_(D_7,D'_11): -0.0
# omega_1_0_(D_7,sink): -0.0
# omega_1_0_(D_8,o_v_0): 0.0
# omega_1_0_(D_8,o_v_1): -0.0
# omega_1_0_(D_8,o_b_0): -0.0
# omega_1_0_(D_8,o_b_1): 0.0
# omega_1_0_(D_8,o_b_2): 0.0
# omega_1_0_(D_8,P_1): 0.0
# omega_1_0_(D_8,P'_4): 0.0
# omega_1_0_(D_8,D_6): 0.0
# omega_1_0_(D_8,D_7): -0.0
# omega_1_0_(D_8,D'_9): -0.0
# omega_1_0_(D_8,D'_10): -0.0
# omega_1_0_(D_8,sink): -0.0
# omega_1_0_(D'_9,o_v_0): 0.0
# omega_1_0_(D'_9,o_v_1): -0.0
# omega_1_0_(D'_9,o_b_0): -0.0
# omega_1_0_(D'_9,o_b_1): 0.0
# omega_1_0_(D'_9,o_b_2): 0.0
# omega_1_0_(D'_9,P_1): 0.0
# omega_1_0_(D'_9,P_2): -0.0
# omega_1_0_(D'_9,P'_4): 0.0
# omega_1_0_(D'_9,P'_5): -0.0
# omega_1_0_(D'_9,D_7): -0.0
# omega_1_0_(D'_9,D_8): -0.0
# omega_1_0_(D'_9,D'_10): -0.0
# omega_1_0_(D'_9,D'_11): -0.0
# omega_1_0_(D'_9,sink): -0.0
# omega_1_0_(D'_10,o_v_0): 0.0
# omega_1_0_(D'_10,o_v_1): -0.0
# omega_1_0_(D'_10,o_b_0): -0.0
# omega_1_0_(D'_10,o_b_1): 0.0
# omega_1_0_(D'_10,o_b_2): 0.0
# omega_1_0_(D'_10,P_2): -0.0
# omega_1_0_(D'_10,P'_5): -0.0
# omega_1_0_(D'_10,D_6): -0.0
# omega_1_0_(D'_10,D_8): -0.0
# omega_1_0_(D'_10,D'_9): -0.0
# omega_1_0_(D'_10,D'_11): -0.0
# omega_1_0_(D'_10,sink): -0.0
# omega_1_0_(D'_11,o_v_0): 0.0
# omega_1_0_(D'_11,o_v_1): -0.0
# omega_1_0_(D'_11,o_b_0): -0.0
# omega_1_0_(D'_11,o_b_1): 0.0
# omega_1_0_(D'_11,o_b_2): 0.0
# omega_1_0_(D'_11,P_1): 0.0
# omega_1_0_(D'_11,P'_4): 0.0
# omega_1_0_(D'_11,D_6): -0.0
# omega_1_0_(D'_11,D_7): -0.0
# omega_1_0_(D'_11,D'_9): -0.0
# omega_1_0_(D'_11,D'_10): -0.0
# omega_1_0_(D'_11,sink): -0.0
# omega_2_0_(o_v_0,o_v_1): -0.0
# omega_2_0_(o_v_0,o_b_0): -0.0
# omega_2_0_(o_v_0,o_b_1): -0.0
# omega_2_0_(o_v_0,o_b_2): -0.0
# omega_2_0_(o_v_0,P_1): -0.0
# omega_2_0_(o_v_0,P_2): -0.0
# omega_2_0_(o_v_0,P'_4): -0.0
# omega_2_0_(o_v_0,P'_5): -0.0
# omega_2_0_(o_v_0,D_6): -0.0
# omega_2_0_(o_v_0,D_7): -0.0
# omega_2_0_(o_v_0,D_8): -0.0
# omega_2_0_(o_v_0,D'_9): -0.0
# omega_2_0_(o_v_0,D'_10): -0.0
# omega_2_0_(o_v_0,D'_11): -0.0
# omega_2_0_(o_v_0,sink): -0.0
# omega_2_0_(o_v_1,o_v_0): 0.0
# omega_2_0_(o_v_1,o_b_0): -0.0
# omega_2_0_(o_v_1,o_b_1): 0.0
# omega_2_0_(o_v_1,o_b_2): 0.0
# omega_2_0_(o_v_1,P_1): 0.0
# omega_2_0_(o_v_1,P_2): -0.0
# omega_2_0_(o_v_1,P'_4): 0.0
# omega_2_0_(o_v_1,P'_5): -0.0
# omega_2_0_(o_v_1,D_6): -0.0
# omega_2_0_(o_v_1,D_7): -0.0
# omega_2_0_(o_v_1,D_8): -0.0
# omega_2_0_(o_v_1,D'_9): -0.0
# omega_2_0_(o_v_1,D'_10): -0.0
# omega_2_0_(o_v_1,D'_11): -0.0
# omega_2_0_(o_v_1,sink): -0.0
# omega_2_0_(o_b_0,o_v_0): 0.0
# omega_2_0_(o_b_0,o_v_1): -0.0
# omega_2_0_(o_b_0,o_b_1): 0.0
# omega_2_0_(o_b_0,o_b_2): 0.0
# omega_2_0_(o_b_0,P_1): 0.0
# omega_2_0_(o_b_0,P_2): -0.0
# omega_2_0_(o_b_0,P'_4): 0.0
# omega_2_0_(o_b_0,P'_5): -0.0
# omega_2_0_(o_b_0,D_6): -0.0
# omega_2_0_(o_b_0,D_7): -0.0
# omega_2_0_(o_b_0,D_8): -0.0
# omega_2_0_(o_b_0,D'_9): -0.0
# omega_2_0_(o_b_0,D'_10): -0.0
# omega_2_0_(o_b_0,D'_11): -0.0
# omega_2_0_(o_b_0,sink): -0.0
# omega_2_0_(o_b_1,o_v_0): -0.0
# omega_2_0_(o_b_1,o_v_1): -0.0
# omega_2_0_(o_b_1,o_b_0): -0.0
# omega_2_0_(o_b_1,o_b_2): -0.0
# omega_2_0_(o_b_1,P_1): -0.0
# omega_2_0_(o_b_1,P_2): -0.0
# omega_2_0_(o_b_1,P'_4): -0.0
# omega_2_0_(o_b_1,P'_5): -0.0
# omega_2_0_(o_b_1,D_6): -0.0
# omega_2_0_(o_b_1,D_7): -0.0
# omega_2_0_(o_b_1,D_8): -0.0
# omega_2_0_(o_b_1,D'_9): -0.0
# omega_2_0_(o_b_1,D'_10): -0.0
# omega_2_0_(o_b_1,D'_11): -0.0
# omega_2_0_(o_b_1,sink): -0.0
# omega_2_0_(o_b_2,o_v_0): -0.0
# omega_2_0_(o_b_2,o_v_1): -0.0
# omega_2_0_(o_b_2,o_b_0): -0.0
# omega_2_0_(o_b_2,o_b_1): -0.0
# omega_2_0_(o_b_2,P_1): -0.0
# omega_2_0_(o_b_2,P_2): -0.0
# omega_2_0_(o_b_2,P'_4): -0.0
# omega_2_0_(o_b_2,P'_5): -0.0
# omega_2_0_(o_b_2,D_6): -0.0
# omega_2_0_(o_b_2,D_7): -0.0
# omega_2_0_(o_b_2,D_8): -0.0
# omega_2_0_(o_b_2,D'_9): -0.0
# omega_2_0_(o_b_2,D'_10): -0.0
# omega_2_0_(o_b_2,D'_11): -0.0
# omega_2_0_(o_b_2,sink): 0.0
# omega_2_0_(P_1,P'_4): -0.0
# omega_2_0_(P_2,P'_5): -0.0
# omega_2_0_(P_1,o_v_0): -0.0
# omega_2_0_(P_1,o_v_1): -0.0
# omega_2_0_(P_1,o_b_0): -0.0
# omega_2_0_(P_1,o_b_1): -0.0
# omega_2_0_(P_1,o_b_2): -0.0
# omega_2_0_(P_1,P_2): -0.0
# omega_2_0_(P_1,P'_5): -0.0
# omega_2_0_(P_1,D_6): -0.0
# omega_2_0_(P_1,D_8): -0.0
# omega_2_0_(P_1,D'_9): -0.0
# omega_2_0_(P_1,D'_11): -0.0
# omega_2_0_(P_1,sink): -0.0
# omega_2_0_(P_2,o_v_0): 0.0
# omega_2_0_(P_2,o_v_1): -0.0
# omega_2_0_(P_2,o_b_0): -0.0
# omega_2_0_(P_2,o_b_1): 0.0
# omega_2_0_(P_2,o_b_2): 0.0
# omega_2_0_(P_2,P_1): 0.0
# omega_2_0_(P_2,P'_4): 0.0
# omega_2_0_(P_2,D_6): -0.0
# omega_2_0_(P_2,D_7): -0.0
# omega_2_0_(P_2,D'_9): -0.0
# omega_2_0_(P_2,D'_10): -0.0
# omega_2_0_(P_2,sink): -0.0
# omega_2_0_(P'_4,D_6): 0.0
# omega_2_0_(P'_5,D_7): 0.0
# omega_2_0_(P'_4,o_v_0): -0.0
# omega_2_0_(P'_4,o_v_1): -0.0
# omega_2_0_(P'_4,o_b_0): -0.0
# omega_2_0_(P'_4,o_b_1): -0.0
# omega_2_0_(P'_4,o_b_2): -0.0
# omega_2_0_(P'_4,P_2): -0.0
# omega_2_0_(P'_4,P'_5): -0.0
# omega_2_0_(P'_4,D_6): 0.0
# omega_2_0_(P'_4,D_8): -0.0
# omega_2_0_(P'_4,D'_9): -0.0
# omega_2_0_(P'_4,D'_11): -0.0
# omega_2_0_(P'_4,sink): -0.0
# omega_2_0_(P'_5,o_v_0): 0.0
# omega_2_0_(P'_5,o_v_1): -0.0
# omega_2_0_(P'_5,o_b_0): -0.0
# omega_2_0_(P'_5,o_b_1): 0.0
# omega_2_0_(P'_5,o_b_2): 0.0
# omega_2_0_(P'_5,P_1): 0.0
# omega_2_0_(P'_5,P'_4): 0.0
# omega_2_0_(P'_5,D_6): -0.0
# omega_2_0_(P'_5,D_7): -0.0
# omega_2_0_(P'_5,D'_9): -0.0
# omega_2_0_(P'_5,D'_10): -0.0
# omega_2_0_(P'_5,sink): -0.0
# omega_2_0_(D_6,D'_9): -0.0
# omega_2_0_(D_7,D'_10): -0.0
# omega_2_0_(D_8,D'_11): -0.0
# omega_2_0_(D_6,o_v_0): 0.0
# omega_2_0_(D_6,o_v_1): -0.0
# omega_2_0_(D_6,o_b_0): 0.0
# omega_2_0_(D_6,o_b_1): 0.0
# omega_2_0_(D_6,o_b_2): 0.0
# omega_2_0_(D_6,P_1): 0.0
# omega_2_0_(D_6,P_2): -0.0
# omega_2_0_(D_6,P'_4): 0.0
# omega_2_0_(D_6,P'_5): -0.0
# omega_2_0_(D_6,D_7): 0.0
# omega_2_0_(D_6,D_8): -0.0
# omega_2_0_(D_6,D'_10): -0.0
# omega_2_0_(D_6,D'_11): -0.0
# omega_2_0_(D_6,sink): -0.0
# omega_2_0_(D_7,o_v_0): 0.0
# omega_2_0_(D_7,o_v_1): -0.0
# omega_2_0_(D_7,o_b_0): -0.0
# omega_2_0_(D_7,o_b_1): 0.0
# omega_2_0_(D_7,o_b_2): 0.0
# omega_2_0_(D_7,P_2): 0.0
# omega_2_0_(D_7,P'_5): -0.0
# omega_2_0_(D_7,D_6): -0.0
# omega_2_0_(D_7,D_8): -0.0
# omega_2_0_(D_7,D'_9): -0.0
# omega_2_0_(D_7,D'_11): -0.0
# omega_2_0_(D_7,sink): -0.0
# omega_2_0_(D_8,o_v_0): 0.0
# omega_2_0_(D_8,o_v_1): -0.0
# omega_2_0_(D_8,o_b_0): -0.0
# ...
# phi_0_(o_b_0,P'_5): 1.0
# phi_0_(o_b_0,D_6): 1.0
# phi_0_(o_b_0,D_7): 1.0
# phi_0_(o_b_0,D_8): 1.0
# phi_0_(o_b_0,D'_9): 1.0
# phi_0_(o_b_0,D'_10): 1.0
# phi_0_(o_b_0,D'_11): 1.0
# phi_0_(o_b_0,sink): 1.0
# phi_0_(o_b_1,o_v_0): 0.0
# phi_0_(o_b_1,o_v_1): 0.0
# phi_0_(o_b_1,o_b_0): 0.0
# phi_0_(o_b_1,o_b_2): -0.0
# phi_0_(o_b_1,P_1): -0.0
# phi_0_(o_b_1,P_2): -0.0
# phi_0_(o_b_1,P'_4): 0.0
# phi_0_(o_b_1,P'_5): 0.0
# phi_0_(o_b_1,D_6): -0.0
# phi_0_(o_b_1,D_7): 0.0
# phi_0_(o_b_1,D_8): -0.0
# phi_0_(o_b_1,D'_9): 0.0
# phi_0_(o_b_1,D'_10): 1.0
# phi_0_(o_b_1,D'_11): 1.0
# phi_0_(o_b_1,sink): 1.0
# phi_0_(o_b_2,o_v_0): 1.0
# phi_0_(o_b_2,o_v_1): 1.0
# phi_0_(o_b_2,o_b_0): 1.0
# phi_0_(o_b_2,o_b_1): 1.0
# phi_0_(o_b_2,P_1): 0.0
# phi_0_(o_b_2,P_2): 1.0
# phi_0_(o_b_2,P'_4): 1.0
# phi_0_(o_b_2,P'_5): 1.0
# phi_0_(o_b_2,D_6): 1.0
# phi_0_(o_b_2,D_7): 1.0
# phi_0_(o_b_2,D_8): 1.0
# phi_0_(o_b_2,D'_9): 1.0
# phi_0_(o_b_2,D'_10): 1.0
# phi_0_(o_b_2,D'_11): 1.0
# phi_0_(o_b_2,sink): 1.0
# phi_0_(P_1,o_v_0): 1.0
# phi_0_(P_1,o_v_1): 1.0
# phi_0_(P_1,o_b_0): 1.0
# phi_0_(P_1,o_b_1): 1.0
# phi_0_(P_1,o_b_2): 1.0
# phi_0_(P_1,P_2): 1.0
# phi_0_(P_1,P'_4): 1.0
# phi_0_(P_1,P'_5): 1.0
# phi_0_(P_1,D_6): 1.0
# phi_0_(P_1,D_7): 0.0
# phi_0_(P_1,D_8): 1.0
# phi_0_(P_1,D'_9): 1.0
# phi_0_(P_1,D'_10): 0.0
# phi_0_(P_1,D'_11): 1.0
# phi_0_(P_1,sink): 1.0
# phi_0_(P_2,o_v_0): 0.0
# phi_0_(P_2,o_v_1): 1.0
# phi_0_(P_2,o_b_0): 0.0
# phi_0_(P_2,o_b_1): 1.0
# phi_0_(P_2,o_b_2): 0.0
# phi_0_(P_2,P_1): 0.0
# phi_0_(P_2,P'_4): 1.0
# phi_0_(P_2,P'_5): 1.0
# phi_0_(P_2,D_6): 1.0
# phi_0_(P_2,D_7): 1.0
# phi_0_(P_2,D_8): 0.0
# phi_0_(P_2,D'_9): 1.0
# phi_0_(P_2,D'_10): 1.0
# phi_0_(P_2,D'_11): 0.0
# phi_0_(P_2,sink): 1.0
# phi_0_(P'_4,o_v_0): 0.0
# phi_0_(P'_4,o_v_1): 1.0
# phi_0_(P'_4,o_b_0): -0.0
# phi_0_(P'_4,o_b_1): 1.0
# phi_0_(P'_4,o_b_2): -0.0
# phi_0_(P'_4,P_1): 0.0
# phi_0_(P'_4,P_2): 0.0
# phi_0_(P'_4,P'_5): 1.0
# phi_0_(P'_4,D_6): 1.0
# phi_0_(P'_4,D_7): 0.0
# phi_0_(P'_4,D_8): 1.0
# phi_0_(P'_4,D'_9): 1.0
# phi_0_(P'_4,D'_10): 0.0
# phi_0_(P'_4,D'_11): 1.0
# phi_0_(P'_4,sink): 1.0
# phi_0_(P'_5,o_v_0): -0.0
# phi_0_(P'_5,o_v_1): 1.0
# phi_0_(P'_5,o_b_0): -0.0
# phi_0_(P'_5,o_b_1): 1.0
# phi_0_(P'_5,o_b_2): -0.0
# phi_0_(P'_5,P_1): -0.0
# phi_0_(P'_5,P_2): 0.0
# phi_0_(P'_5,P'_4): -0.0
# phi_0_(P'_5,D_6): 1.0
# phi_0_(P'_5,D_7): -0.0
# phi_0_(P'_5,D_8): 0.0
# phi_0_(P'_5,D'_9): 1.0
# phi_0_(P'_5,D'_10): 1.0
# phi_0_(P'_5,D'_11): 0.0
# phi_0_(P'_5,sink): 1.0
# phi_0_(D_6,o_v_0): 0.0
# phi_0_(D_6,o_v_1): 0.0
# phi_0_(D_6,o_b_0): 0.0
# phi_0_(D_6,o_b_1): 1.0
# phi_0_(D_6,o_b_2): 0.0
# phi_0_(D_6,P_1): -0.0
# phi_0_(D_6,P_2): 0.0
# phi_0_(D_6,P'_4): 0.0
# phi_0_(D_6,P'_5): 0.0
# phi_0_(D_6,D_7): 0.0
# phi_0_(D_6,D_8): 0.0
# phi_0_(D_6,D'_9): 1.0
# phi_0_(D_6,D'_10): 1.0
# phi_0_(D_6,D'_11): 1.0
# phi_0_(D_6,sink): 1.0
# phi_0_(D_7,o_v_0): 0.0
# phi_0_(D_7,o_v_1): 1.0
# phi_0_(D_7,o_b_0): 0.0
# phi_0_(D_7,o_b_1): 1.0
# phi_0_(D_7,o_b_2): 0.0
# phi_0_(D_7,P_1): 0.0
# phi_0_(D_7,P_2): -0.0
# phi_0_(D_7,P'_4): 0.0
# phi_0_(D_7,P'_5): 1.0
# phi_0_(D_7,D_6): 1.0
# phi_0_(D_7,D_8): 0.0
# phi_0_(D_7,D'_9): 1.0
# phi_0_(D_7,D'_10): 1.0
# phi_0_(D_7,D'_11): 1.0
# phi_0_(D_7,sink): 1.0
# phi_0_(D_8,o_v_0): 0.0
# phi_0_(D_8,o_v_1): 1.0
# phi_0_(D_8,o_b_0): 0.0
# phi_0_(D_8,o_b_1): 1.0
# phi_0_(D_8,o_b_2): 0.0
# phi_0_(D_8,P_1): 0.0
# phi_0_(D_8,P_2): 0.0
# phi_0_(D_8,P'_4): 0.0
# phi_0_(D_8,P'_5): 0.0
# phi_0_(D_8,D_6): 1.0
# phi_0_(D_8,D_7): 1.0
# phi_0_(D_8,D'_9): 1.0
# phi_0_(D_8,D'_10): 1.0
# phi_0_(D_8,D'_11): 1.0
# phi_0_(D_8,sink): 1.0
# phi_0_(D'_9,o_v_0): -0.0
# phi_0_(D'_9,o_v_1): 0.0
# phi_0_(D'_9,o_b_0): -0.0
# phi_0_(D'_9,o_b_1): 1.0
# phi_0_(D'_9,o_b_2): -0.0
# phi_0_(D'_9,P_1): -0.0
# phi_0_(D'_9,P_2): 0.0
# phi_0_(D'_9,P'_4): -0.0
# phi_0_(D'_9,P'_5): 0.0
# phi_0_(D'_9,D_6): 0.0
# phi_0_(D'_9,D_7): -0.0
# phi_0_(D'_9,D_8): 0.0
# phi_0_(D'_9,D'_10): 1.0
# phi_0_(D'_9,D'_11): 1.0
# phi_0_(D'_9,sink): 1.0
# phi_0_(D'_10,o_v_0): -0.0
# phi_0_(D'_10,o_v_1): -0.0
# phi_0_(D'_10,o_b_0): -0.0
# phi_0_(D'_10,o_b_1): -0.0
# phi_0_(D'_10,o_b_2): -0.0
# phi_0_(D'_10,P_1): 0.0
# phi_0_(D'_10,P_2): -0.0
# phi_0_(D'_10,P'_4): 0.0
# phi_0_(D'_10,P'_5): -0.0
# phi_0_(D'_10,D_6): -0.0
# phi_0_(D'_10,D_7): 0.0
# phi_0_(D'_10,D_8): -0.0
# phi_0_(D'_10,D'_9): 0.0
# phi_0_(D'_10,D'_11): -0.0
# phi_0_(D'_10,sink): 1.0
# phi_0_(D'_11,o_v_0): 0.0
# phi_0_(D'_11,o_v_1): -0.0
# phi_0_(D'_11,o_b_0): -0.0
# phi_0_(D'_11,o_b_1): -0.0
# phi_0_(D'_11,o_b_2): -0.0
# phi_0_(D'_11,P_1): -0.0
# phi_0_(D'_11,P_2): 0.0
# phi_0_(D'_11,P'_4): -0.0
# phi_0_(D'_11,P'_5): 0.0
# phi_0_(D'_11,D_6): -0.0
# phi_0_(D'_11,D_7): 0.0
# phi_0_(D'_11,D_8): 0.0
# phi_0_(D'_11,D'_9): 0.0
# phi_0_(D'_11,D'_10): 1.0
# phi_0_(D'_11,sink): 1.0
# phi_0_(sink,o_v_0): 0.0
# phi_0_(sink,o_v_1): 0.0
# phi_0_(sink,o_b_0): 0.0
# phi_0_(sink,o_b_1): 0.0
# phi_0_(sink,o_b_2): 0.0
# phi_0_(sink,P_1): 0.0
# phi_0_(sink,P_2): 0.0
# phi_0_(sink,P'_4): 0.0
# phi_0_(sink,P'_5): 0.0
# phi_0_(sink,D_6): 0.0
# phi_0_(sink,D_7): 0.0
# phi_0_(sink,D_8): 0.0
# phi_0_(sink,D'_9): 0.0
# phi_0_(sink,D'_10): 0.0
# phi_0_(sink,D'_11): 0.0
# phi_1_(o_v_0,o_v_1): 0.0
# phi_1_(o_v_0,o_b_0): -0.0
# phi_1_(o_v_0,o_b_1): -0.0
# phi_1_(o_v_0,o_b_2): -0.0
# phi_1_(o_v_0,P_1): 0.0
# phi_1_(o_v_0,P_2): -0.0
# phi_1_(o_v_0,P'_4): 0.0
# phi_1_(o_v_0,P'_5): 1.0
# phi_1_(o_v_0,D_6): 0.0
# phi_1_(o_v_0,D_7): -0.0
# phi_1_(o_v_0,D_8): 1.0
# phi_1_(o_v_0,D'_9): 1.0
# phi_1_(o_v_0,D'_10): 1.0
# phi_1_(o_v_0,D'_11): 1.0
# phi_1_(o_v_0,sink): 1.0
# phi_1_(o_v_1,o_v_0): 1.0
# phi_1_(o_v_1,o_b_0): -0.0
# phi_1_(o_v_1,o_b_1): -0.0
# phi_1_(o_v_1,o_b_2): -0.0
# phi_1_(o_v_1,P_1): -0.0
# phi_1_(o_v_1,P_2): -0.0
# phi_1_(o_v_1,P'_4): 0.0
# phi_1_(o_v_1,P'_5): 1.0
# phi_1_(o_v_1,D_6): 0.0
# phi_1_(o_v_1,D_7): -0.0
# phi_1_(o_v_1,D_8): 1.0
# phi_1_(o_v_1,D'_9): 1.0
# phi_1_(o_v_1,D'_10): 1.0
# phi_1_(o_v_1,D'_11): 1.0
# phi_1_(o_v_1,sink): 1.0
# phi_1_(o_b_0,o_v_0): 1.0
# phi_1_(o_b_0,o_v_1): 1.0
# phi_1_(o_b_0,o_b_1): -0.0
# phi_1_(o_b_0,o_b_2): -0.0
# phi_1_(o_b_0,P_1): -0.0
# phi_1_(o_b_0,P_2): -0.0
# phi_1_(o_b_0,P'_4): 0.0
# phi_1_(o_b_0,P'_5): 1.0
# phi_1_(o_b_0,D_6): 0.0
# phi_1_(o_b_0,D_7): -0.0
# phi_1_(o_b_0,D_8): 1.0
# phi_1_(o_b_0,D'_9): 1.0
# phi_1_(o_b_0,D'_10): 1.0
# phi_1_(o_b_0,D'_11): 1.0
# phi_1_(o_b_0,sink): 1.0
# phi_1_(o_b_1,o_v_0): 1.0
# phi_1_(o_b_1,o_v_1): 1.0
# phi_1_(o_b_1,o_b_0): 1.0
# phi_1_(o_b_1,o_b_2): 1.0
# phi_1_(o_b_1,P_1): 1.0
# phi_1_(o_b_1,P_2): 1.0
# phi_1_(o_b_1,P'_4): 1.0
# phi_1_(o_b_1,P'_5): 1.0
# phi_1_(o_b_1,D_6): 1.0
# phi_1_(o_b_1,D_7): 1.0
# phi_1_(o_b_1,D_8): 1.0
# phi_1_(o_b_1,D'_9): 1.0
# phi_1_(o_b_1,D'_10): 1.0
# phi_1_(o_b_1,D'_11): 1.0
# phi_1_(o_b_1,sink): 1.0
# phi_1_(o_b_2,o_v_0): 1.0
# phi_1_(o_b_2,o_v_1): 1.0
# phi_1_(o_b_2,o_b_0): 1.0
# phi_1_(o_b_2,o_b_1): 0.0
# phi_1_(o_b_2,P_1): -0.0
# phi_1_(o_b_2,P_2): -0.0
# phi_1_(o_b_2,P'_4): 0.0
# phi_1_(o_b_2,P'_5): 1.0
# phi_1_(o_b_2,D_6): 0.0
# phi_1_(o_b_2,D_7): -0.0
# phi_1_(o_b_2,D_8): 1.0
# phi_1_(o_b_2,D'_9): 1.0
# phi_1_(o_b_2,D'_10): 1.0
# phi_1_(o_b_2,D'_11): 1.0
# phi_1_(o_b_2,sink): 1.0
# phi_1_(P_1,o_v_0): 1.0
# phi_1_(P_1,o_v_1): 1.0
# phi_1_(P_1,o_b_0): 1.0
# phi_1_(P_1,o_b_1): 0.0
# phi_1_(P_1,o_b_2): 1.0
# phi_1_(P_1,P_2): 1.0
# phi_1_(P_1,P'_4): 1.0
# phi_1_(P_1,P'_5): 1.0
# phi_1_(P_1,D_6): 1.0
# phi_1_(P_1,D_7): 0.0
# phi_1_(P_1,D_8): 1.0
# phi_1_(P_1,D'_9): 1.0
# phi_1_(P_1,D'_10): 0.0
# phi_1_(P_1,D'_11): 1.0
# phi_1_(P_1,sink): 1.0
# phi_1_(P_2,o_v_0): 1.0
# phi_1_(P_2,o_v_1): 1.0
# phi_1_(P_2,o_b_0): 1.0
# phi_1_(P_2,o_b_1): 0.0
# phi_1_(P_2,o_b_2): 1.0
# phi_1_(P_2,P_1): 0.0
# phi_1_(P_2,P'_4): 0.0
# phi_1_(P_2,P'_5): 1.0
# phi_1_(P_2,D_6): 1.0
# phi_1_(P_2,D_7): 1.0
# phi_1_(P_2,D_8): 0.0
# phi_1_(P_2,D'_9): 1.0
# phi_1_(P_2,D'_10): 1.0
# phi_1_(P_2,D'_11): 0.0
# phi_1_(P_2,sink): 1.0
# phi_1_(P'_4,o_v_0): 1.0
# phi_1_(P'_4,o_v_1): 1.0
# phi_1_(P'_4,o_b_0): 1.0
# phi_1_(P'_4,o_b_1): -0.0
# phi_1_(P'_4,o_b_2): 1.0
# phi_1_(P'_4,P_1): 0.0
# phi_1_(P'_4,P_2): 1.0
# phi_1_(P'_4,P'_5): 1.0
# phi_1_(P'_4,D_6): 1.0
# phi_1_(P'_4,D_7): 0.0
# phi_1_(P'_4,D_8): 1.0
# phi_1_(P'_4,D'_9): 1.0
# phi_1_(P'_4,D'_10): 0.0
# phi_1_(P'_4,D'_11): 1.0
# phi_1_(P'_4,sink): 1.0
# phi_1_(P'_5,o_v_0): -0.0
# phi_1_(P'_5,o_v_1): 0.0
# phi_1_(P'_5,o_b_0): -0.0
# phi_1_(P'_5,o_b_1): -0.0
# phi_1_(P'_5,o_b_2): -0.0
# phi_1_(P'_5,P_1): -0.0
# phi_1_(P'_5,P_2): 0.0
# phi_1_(P'_5,P'_4): -0.0
# phi_1_(P'_5,D_6): -0.0
# phi_1_(P'_5,D_7): -0.0
# phi_1_(P'_5,D_8): 0.0
# phi_1_(P'_5,D'_9): 1.0
# phi_1_(P'_5,D'_10): 1.0
# phi_1_(P'_5,D'_11): 0.0
# phi_1_(P'_5,sink): 1.0
# phi_1_(D_6,o_v_0): 1.0
# phi_1_(D_6,o_v_1): 1.0
# phi_1_(D_6,o_b_0): 1.0
# phi_1_(D_6,o_b_1): 0.0
# phi_1_(D_6,o_b_2): 1.0
# phi_1_(D_6,P_1): -0.0
# phi_1_(D_6,P_2): -0.0
# phi_1_(D_6,P'_4): 0.0
# phi_1_(D_6,P'_5): 1.0
# phi_1_(D_6,D_7): 0.0
# phi_1_(D_6,D_8): 1.0
# phi_1_(D_6,D'_9): 1.0
# phi_1_(D_6,D'_10): 1.0
# phi_1_(D_6,D'_11): 1.0
# phi_1_(D_6,sink): 1.0
# phi_1_(D_7,o_v_0): 1.0
# phi_1_(D_7,o_v_1): 1.0
# phi_1_(D_7,o_b_0): 1.0
# phi_1_(D_7,o_b_1): 0.0
# phi_1_(D_7,o_b_2): 1.0
# phi_1_(D_7,P_1): 0.0
# phi_1_(D_7,P_2): -0.0
# phi_1_(D_7,P'_4): 0.0
# phi_1_(D_7,P'_5): 1.0
# phi_1_(D_7,D_6): 1.0
# phi_1_(D_7,D_8): 1.0
# phi_1_(D_7,D'_9): 1.0
# phi_1_(D_7,D'_10): 1.0
# phi_1_(D_7,D'_11): 1.0
# phi_1_(D_7,sink): 1.0
# phi_1_(D_8,o_v_0): 0.0
# phi_1_(D_8,o_v_1): 0.0
# phi_1_(D_8,o_b_0): 0.0
# phi_1_(D_8,o_b_1): 0.0
# phi_1_(D_8,o_b_2): 0.0
# phi_1_(D_8,P_1): 0.0
# phi_1_(D_8,P_2): 0.0
# phi_1_(D_8,P'_4): 0.0
# phi_1_(D_8,P'_5): 0.0
# phi_1_(D_8,D_6): 0.0
# phi_1_(D_8,D_7): 0.0
# phi_1_(D_8,D'_9): 1.0
# phi_1_(D_8,D'_10): 1.0
# phi_1_(D_8,D'_11): 1.0
# phi_1_(D_8,sink): 1.0
# phi_1_(D'_9,o_v_0): -0.0
# phi_1_(D'_9,o_v_1): -0.0
# phi_1_(D'_9,o_b_0): -0.0
# phi_1_(D'_9,o_b_1): -0.0
# phi_1_(D'_9,o_b_2): -0.0
# phi_1_(D'_9,P_1): -0.0
# phi_1_(D'_9,P_2): -0.0
# phi_1_(D'_9,P'_4): -0.0
# phi_1_(D'_9,P'_5): -0.0
# phi_1_(D'_9,D_6): 0.0
# phi_1_(D'_9,D_7): -0.0
# phi_1_(D'_9,D_8): -0.0
# phi_1_(D'_9,D'_10): 0.0
# phi_1_(D'_9,D'_11): 1.0
# phi_1_(D'_9,sink): 1.0
# phi_1_(D'_10,o_v_0): -0.0
# phi_1_(D'_10,o_v_1): -0.0
# phi_1_(D'_10,o_b_0): -0.0
# phi_1_(D'_10,o_b_1): -0.0
# phi_1_(D'_10,o_b_2): -0.0
# phi_1_(D'_10,P_1): 0.0
# phi_1_(D'_10,P_2): -0.0
# phi_1_(D'_10,P'_4): 0.0
# phi_1_(D'_10,P'_5): -0.0
# phi_1_(D'_10,D_6): -0.0
# phi_1_(D'_10,D_7): 0.0
# phi_1_(D'_10,D_8): -0.0
# phi_1_(D'_10,D'_9): 1.0
# phi_1_(D'_10,D'_11): 1.0
# phi_1_(D'_10,sink): 1.0
# phi_1_(D'_11,o_v_0): -0.0
# phi_1_(D'_11,o_v_1): -0.0
# phi_1_(D'_11,o_b_0): -0.0
# phi_1_(D'_11,o_b_1): -0.0
# phi_1_(D'_11,o_b_2): -0.0
# phi_1_(D'_11,P_1): -0.0
# phi_1_(D'_11,P_2): 0.0
# phi_1_(D'_11,P'_4): -0.0
# phi_1_(D'_11,P'_5): 0.0
# phi_1_(D'_11,D_6): -0.0
# phi_1_(D'_11,D_7): -0.0
# phi_1_(D'_11,D_8): 0.0
# phi_1_(D'_11,D'_9): 0.0
# phi_1_(D'_11,D'_10): 0.0
# phi_1_(D'_11,sink): 1.0
# phi_1_(sink,o_v_0): 0.0
# phi_1_(sink,o_v_1): 0.0
# phi_1_(sink,o_b_0): 0.0
# phi_1_(sink,o_b_1): 0.0
# phi_1_(sink,o_b_2): 0.0
# phi_1_(sink,P_1): 0.0
# phi_1_(sink,P_2): 0.0
# phi_1_(sink,P'_4): 0.0
# phi_1_(sink,P'_5): 0.0
# phi_1_(sink,D_6): 0.0
# phi_1_(sink,D_7): 0.0
# phi_1_(sink,D_8): 0.0
# phi_1_(sink,D'_9): 0.0
# phi_1_(sink,D'_10): 0.0
# phi_1_(sink,D'_11): 0.0
# phi_2_(o_v_0,o_v_1): 1.0
# phi_2_(o_v_0,o_b_0): 1.0
# phi_2_(o_v_0,o_b_1): 0.0
# phi_2_(o_v_0,o_b_2): -0.0
# phi_2_(o_v_0,P_1): -0.0
# phi_2_(o_v_0,P_2): 1.0
# phi_2_(o_v_0,P'_4): 0.0
# phi_2_(o_v_0,P'_5): 1.0
# phi_2_(o_v_0,D_6): 1.0
# phi_2_(o_v_0,D_7): 1.0
# phi_2_(o_v_0,D_8): 1.0
# phi_2_(o_v_0,D'_9): 1.0
# phi_2_(o_v_0,D'_10): 1.0
# phi_2_(o_v_0,D'_11): 1.0
# phi_2_(o_v_0,sink): 1.0
# phi_2_(o_v_1,o_v_0): 0.0
# phi_2_(o_v_1,o_b_0): 0.0
# phi_2_(o_v_1,o_b_1): -0.0
# phi_2_(o_v_1,o_b_2): -0.0
# phi_2_(o_v_1,P_1): -0.0
# phi_2_(o_v_1,P_2): -0.0
# phi_2_(o_v_1,P'_4): 0.0
# phi_2_(o_v_1,P'_5): 0.0
# phi_2_(o_v_1,D_6): 0.0
# phi_2_(o_v_1,D_7): 0.0
# phi_2_(o_v_1,D_8): 1.0
# phi_2_(o_v_1,D'_9): 1.0
# phi_2_(o_v_1,D'_10): 0.0
# phi_2_(o_v_1,D'_11): 1.0
# phi_2_(o_v_1,sink): 1.0
# phi_2_(o_b_0,o_v_0): 0.0
# phi_2_(o_b_0,o_v_1): 1.0
# phi_2_(o_b_0,o_b_1): -0.0
# phi_2_(o_b_0,o_b_2): -0.0
# phi_2_(o_b_0,P_1): -0.0
# phi_2_(o_b_0,P_2): -0.0
# phi_2_(o_b_0,P'_4): 0.0
# phi_2_(o_b_0,P'_5): 0.0
# phi_2_(o_b_0,D_6): 1.0
# phi_2_(o_b_0,D_7): 1.0
# phi_2_(o_b_0,D_8): 1.0
# phi_2_(o_b_0,D'_9): 1.0
# phi_2_(o_b_0,D'_10): 1.0
# phi_2_(o_b_0,D'_11): 1.0
# phi_2_(o_b_0,sink): 1.0
# phi_2_(o_b_1,o_v_0): 1.0
# phi_2_(o_b_1,o_v_1): 1.0
# phi_2_(o_b_1,o_b_0): 1.0
# phi_2_(o_b_1,o_b_2): -0.0
# phi_2_(o_b_1,P_1): -0.0
# phi_2_(o_b_1,P_2): 1.0
# phi_2_(o_b_1,P'_4): 0.0
# phi_2_(o_b_1,P'_5): 1.0
# phi_2_(o_b_1,D_6): 1.0
# phi_2_(o_b_1,D_7): 1.0
# phi_2_(o_b_1,D_8): 1.0
# phi_2_(o_b_1,D'_9): 1.0
# phi_2_(o_b_1,D'_10): 1.0
# phi_2_(o_b_1,D'_11): 1.0
# phi_2_(o_b_1,sink): 1.0
# phi_2_(o_b_2,o_v_0): 1.0
# phi_2_(o_b_2,o_v_1): 1.0
# phi_2_(o_b_2,o_b_0): 1.0
# phi_2_(o_b_2,o_b_1): 1.0
# phi_2_(o_b_2,P_1): 1.0
# phi_2_(o_b_2,P_2): 1.0
# phi_2_(o_b_2,P'_4): 1.0
# phi_2_(o_b_2,P'_5): 1.0
# phi_2_(o_b_2,D_6): 1.0
# phi_2_(o_b_2,D_7): 1.0
# phi_2_(o_b_2,D_8): 1.0
# phi_2_(o_b_2,D'_9): 1.0
# phi_2_(o_b_2,D'_10): 1.0
# phi_2_(o_b_2,D'_11): 1.0
# phi_2_(o_b_2,sink): 1.0
# phi_2_(P_1,o_v_0): 1.0
# phi_2_(P_1,o_v_1): 1.0
# phi_2_(P_1,o_b_0): 1.0
# phi_2_(P_1,o_b_1): 1.0
# phi_2_(P_1,o_b_2): 0.0
# phi_2_(P_1,P_2): 1.0
# phi_2_(P_1,P'_4): 1.0
# phi_2_(P_1,P'_5): 1.0
# phi_2_(P_1,D_6): 1.0
# phi_2_(P_1,D_7): 0.0
# phi_2_(P_1,D_8): 1.0
# phi_2_(P_1,D'_9): 1.0
# phi_2_(P_1,D'_10): 0.0
# phi_2_(P_1,D'_11): 1.0
# phi_2_(P_1,sink): 1.0
# phi_2_(P_2,o_v_0): 0.0
# phi_2_(P_2,o_v_1): 1.0
# phi_2_(P_2,o_b_0): 1.0
# phi_2_(P_2,o_b_1): 0.0
# phi_2_(P_2,o_b_2): 0.0
# phi_2_(P_2,P_1): 0.0
# phi_2_(P_2,P'_4): 0.0
# phi_2_(P_2,P'_5): 1.0
# phi_2_(P_2,D_6): 1.0
# phi_2_(P_2,D_7): 1.0
# phi_2_(P_2,D_8): 0.0
# phi_2_(P_2,D'_9): 1.0
# phi_2_(P_2,D'_10): 1.0
# phi_2_(P_2,D'_11): 0.0
# phi_2_(P_2,sink): 1.0
# phi_2_(P'_4,o_v_0): 1.0
# phi_2_(P'_4,o_v_1): 1.0
# phi_2_(P'_4,o_b_0): 1.0
# phi_2_(P'_4,o_b_1): 1.0
# phi_2_(P'_4,o_b_2): -0.0
# phi_2_(P'_4,P_1): 0.0
# phi_2_(P'_4,P_2): 1.0
# phi_2_(P'_4,P'_5): 1.0
# phi_2_(P'_4,D_6): 1.0
# phi_2_(P'_4,D_7): 0.0
# phi_2_(P'_4,D_8): 1.0
# phi_2_(P'_4,D'_9): 1.0
# phi_2_(P'_4,D'_10): 0.0
# phi_2_(P'_4,D'_11): 1.0
# phi_2_(P'_4,sink): 1.0
# phi_2_(P'_5,o_v_0): -0.0
# phi_2_(P'_5,o_v_1): 1.0
# phi_2_(P'_5,o_b_0): 1.0
# phi_2_(P'_5,o_b_1): -0.0
# phi_2_(P'_5,o_b_2): -0.0
# phi_2_(P'_5,P_1): -0.0
# phi_2_(P'_5,P_2): 0.0
# phi_2_(P'_5,P'_4): -0.0
# phi_2_(P'_5,D_6): 1.0
# phi_2_(P'_5,D_7): 1.0
# phi_2_(P'_5,D_8): 0.0
# phi_2_(P'_5,D'_9): 1.0
# phi_2_(P'_5,D'_10): 1.0
# phi_2_(P'_5,D'_11): 0.0
# phi_2_(P'_5,sink): 1.0
# phi_2_(D_6,o_v_0): 0.0
# phi_2_(D_6,o_v_1): 1.0
# phi_2_(D_6,o_b_0): 0.0
# phi_2_(D_6,o_b_1): 0.0
# phi_2_(D_6,o_b_2): 0.0
# phi_2_(D_6,P_1): -0.0
# phi_2_(D_6,P_2): -0.0
# phi_2_(D_6,P'_4): 0.0
# phi_2_(D_6,P'_5): 0.0
# phi_2_(D_6,D_7): 0.0
# phi_2_(D_6,D_8): 1.0
# phi_2_(D_6,D'_9): 1.0
# phi_2_(D_6,D'_10): 0.0
# phi_2_(D_6,D'_11): 1.0
# phi_2_(D_6,sink): 1.0
# phi_2_(D_7,o_v_0): 0.0
# phi_2_(D_7,o_v_1): 1.0
# phi_2_(D_7,o_b_0): 0.0
# phi_2_(D_7,o_b_1): 0.0
# phi_2_(D_7,o_b_2): 0.0
# phi_2_(D_7,P_1): 0.0
# phi_2_(D_7,P_2): -0.0
# phi_2_(D_7,P'_4): 0.0
# phi_2_(D_7,P'_5): 0.0
# phi_2_(D_7,D_6): 1.0
# phi_2_(D_7,D_8): 1.0
# phi_2_(D_7,D'_9): 1.0
# phi_2_(D_7,D'_10): 1.0
# phi_2_(D_7,D'_11): 1.0
# phi_2_(D_7,sink): 1.0
# phi_2_(D_8,o_v_0): 0.0
# phi_2_(D_8,o_v_1): 0.0
# phi_2_(D_8,o_b_0): 0.0
# phi_2_(D_8,o_b_1): 0.0
# phi_2_(D_8,o_b_2): 0.0
# phi_2_(D_8,P_1): 0.0
# phi_2_(D_8,P_2): 0.0
# phi_2_(D_8,P'_4): 0.0
# phi_2_(D_8,P'_5): 0.0
# phi_2_(D_8,D_6): 0.0
# phi_2_(D_8,D_7): 0.0
# phi_2_(D_8,D'_9): 1.0
# phi_2_(D_8,D'_10): 0.0
# phi_2_(D_8,D'_11): 1.0
# phi_2_(D_8,sink): 1.0
# phi_2_(D'_9,o_v_0): -0.0
# phi_2_(D'_9,o_v_1): 0.0
# phi_2_(D'_9,o_b_0): -0.0
# phi_2_(D'_9,o_b_1): -0.0
# phi_2_(D'_9,o_b_2): -0.0
# phi_2_(D'_9,P_1): -0.0
# phi_2_(D'_9,P_2): -0.0
# phi_2_(D'_9,P'_4): -0.0
# phi_2_(D'_9,P'_5): -0.0
# phi_2_(D'_9,D_6): 0.0
# phi_2_(D'_9,D_7): -0.0
# phi_2_(D'_9,D_8): 0.0
# phi_2_(D'_9,D'_10): -0.0
# phi_2_(D'_9,D'_11): 0.0
# phi_2_(D'_9,sink): 1.0
# phi_2_(D'_10,o_v_0): -0.0
# phi_2_(D'_10,o_v_1): 1.0
# phi_2_(D'_10,o_b_0): 0.0
# phi_2_(D'_10,o_b_1): -0.0
# phi_2_(D'_10,o_b_2): -0.0
# phi_2_(D'_10,P_1): 0.0
# phi_2_(D'_10,P_2): -0.0
# phi_2_(D'_10,P'_4): 0.0
# phi_2_(D'_10,P'_5): -0.0
# phi_2_(D'_10,D_6): 1.0
# phi_2_(D'_10,D_7): 0.0
# phi_2_(D'_10,D_8): 1.0
# phi_2_(D'_10,D'_9): 1.0
# phi_2_(D'_10,D'_11): 1.0
# phi_2_(D'_10,sink): 1.0
# phi_2_(D'_11,o_v_0): -0.0
# phi_2_(D'_11,o_v_1): -0.0
# phi_2_(D'_11,o_b_0): -0.0
# phi_2_(D'_11,o_b_1): -0.0
# phi_2_(D'_11,o_b_2): -0.0
# phi_2_(D'_11,P_1): -0.0
# phi_2_(D'_11,P_2): 0.0
# phi_2_(D'_11,P'_4): -0.0
# phi_2_(D'_11,P'_5): 0.0
# phi_2_(D'_11,D_6): -0.0
# phi_2_(D'_11,D_7): -0.0
# phi_2_(D'_11,D_8): 0.0
# phi_2_(D'_11,D'_9): 1.0
# phi_2_(D'_11,D'_10): 0.0
# phi_2_(D'_11,sink): 1.0
# phi_2_(sink,o_v_0): 0.0
# phi_2_(sink,o_v_1): 0.0
# phi_2_(sink,o_b_0): 0.0
# phi_2_(sink,o_b_1): 0.0
# phi_2_(sink,o_b_2): 0.0
# phi_2_(sink,P_1): 0.0
# phi_2_(sink,P_2): 0.0
# phi_2_(sink,P'_4): 0.0
# phi_2_(sink,P'_5): 0.0
# phi_2_(sink,D_6): 0.0
# phi_2_(sink,D_7): 0.0
# phi_2_(sink,D_8): 0.0
# phi_2_(sink,D'_9): 0.0
# phi_2_(sink,D'_10): 0.0
# phi_2_(sink,D'_11): 0.0

# %%
t = tau_a[0]
for arc in t:
    if(t[arc].x == 1):
        print(arc)
# Out:
# o_b_0
# P_2
# P'_5
# D_8
# D'_9
# sink

# %%
Requests
# Out:
# <gurobi.tuplelist (3 tuples, 9 values each):
#  ( 0 , -1 , -1   , -1   , 3 , 20669 , 21257 , 7 , 0  )
#  ( 1 , 0  , 7283 , 8286 , 2 , 16933 , 20531 , 6 , -1 )
#  ( 2 , 3  , 8213 , 8250 , 1 , 15748 , 16920 , 8 , -1 )
# >

# %%
Bodies
# Out:
# <gurobi.tuplelist (3 tuples, 3 values each):
#  ( 0 , 1 , 2 )
#  ( 1 , 0 , 0 )
#  ( 2 , 0 , 0 )
# >

# %%
Vessels
# Out:
# <gurobi.tuplelist (2 tuples, 3 values each):
#  ( 0 , 0 , 0 )
#  ( 1 , 2 , 0 )
# >

# %%
nodes_locations["D_6"]
# Out:
# 3
